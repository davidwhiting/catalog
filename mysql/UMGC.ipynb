# %% [markdown]
# # Create Catalog
# ## Convert PDF to TXT

# %%
import sys
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfparser import PDFParser
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfdevice import PDFDevice, TagExtractor
from pdfminer.pdfpage import PDFPage
from pdfminer.converter import TextConverter
from pdfminer.cmapdb import CMapDB
from pdfminer.layout import LTTextContainer, LAParams
from pdfminer.image import ImageWriter

def pdf_to_txt(outfile='tmp_pdf2txt.txt', infile='2023-2024-catalog-courses.pdf', 
               pages='', maxpages=0, password=b'', debug=0 ):

    # input option
    pagenos = set()
    if pages != '':
        pagenos.update( int(x)-1 for x in pages.split(',') )
    imagewriter = None
    rotation = 0
    stripcontrol = False
    layoutmode = 'normal'
    encoding = 'utf-8'
    pageno = 1
    scale = 1
    caching = True
    showpageno = True
    laparams = LAParams()
    #
    rsrcmgr = PDFResourceManager(caching=caching)
    outfp = open(outfile, 'w', encoding=encoding)
    device = TextConverter(rsrcmgr, outfp, laparams=laparams, imagewriter=None)
    with open(infile, 'rb') as fp:
        interpreter = PDFPageInterpreter(rsrcmgr, device)
        for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,
                                      caching=caching, check_extractable=True):
            interpreter.process_page(page)
    device.close()
    outfp.close()
    return

# %%
pdf_to_txt()

# %% [markdown]
# ## Functions for Creating Courses

# %% [markdown]
# ### Regular Expressions

# %%
import re

# Course Start and End patterns
course_pattern = re.compile(r'^([A-Z]{3}[A-Z]? \d{3}[A-Z]?) ([A-Z].+?) \((\d(?:–\d)?)\)$')
course_start_pattern = re.compile(r'^([A-Z]{3}[A-Z]? \d{3}[A-Z]?) ([A-Z].+?)$')
course_end_pattern = re.compile(r'^(.+?) \((\d(?:–\d)?)\)$')

# Prerequisites
prerequisite_pattern = re.compile(r'Prerequisites?:\s(.*?)(?=\.\s|\.\))', re.DOTALL)
    
# Recommended
recommended_pattern = re.compile(r'Recommended:\s([^\.]+)\.\s')
    
# Substitutions
substitution_pattern = re.compile(r'may\s+receive\s+credit\s+for\s+only\s+one\s+of\s+the\s+following\s+courses: ')

# Warnings 
warning_pattern = re.compile(r'^\(([^\)]+)\)')

# %%
def create_new_course(name, title, credit):
    course = {
        'name': name.strip(),
        'title': title.strip(),
        'credit': credit.strip(),
        'description': '',
        'prerequisites': '',
        'recommended': '',
        'warnings': '',
        'substitutions': ''
    }
    return course

def update_description(course, sub=substitution_pattern, pre=prerequisite_pattern, 
                       warn=warning_pattern, recd=recommended_pattern):
    description = re.sub(r'\n', '', course['description'])
    # Substitutions
    submatch = sub.search(description)
    if submatch:
        start, end = submatch.span()
        course['substitutions'] = description[end:-1].strip()
    # Prerequisites
    prematch = pre.search(description)
    if prematch:
        course['prerequisites'] = prematch.group(1)
    # Recommended
    recmatch = recd.search(description)
    if recmatch:
        course['recommended'] = recmatch.group(1)
    # Warnings
    warnmatch = warn.search(description)
    if warnmatch:
        course['warnings'] = warnmatch.group(1)
    
    return course

def parse_course_info(text):
    
    # Logic Overview
    #
    # A course starts by matching a pattern, either
    #
    #     OneLine = STAT 221 Introduction to Statistics (3)
    # or
    #     TwoLine = STAT 536 A Really Long Description that 
    #               Takes Up More than One Line (1-3)
    #
    # - `course_match` will match OneLine and a new course is created
    # - `course_match_start` will match the first line of TwoLine 
    #   and make the variable `start_course = True`
    # - `course_match_end` will match the second line of TwoLine and
    #   a new course is created. This is checked only if the variable 
    #   `start_course = True`
    # - `course_match` and `course_match_end` will turn on the indicator
    #   variable `description_on = True`
    # - a blank line will set `description_on = False` and indicates
    #   the end of the course.
    # - after a course is ended, it is moved to `prior_course` and the
    #   description is parsed to populate warnings, prerequisites, and 
    #   recommended in the course
    
    courses = []
    prior_course = None
    current_course = None
    start_course = False
    add_description = False

    for line in text.split('\n'):
        
        course_match = course_pattern.search(line)
        course_match_start = course_start_pattern.search(line)
        course_match_end = course_end_pattern.search(line)

        if start_course:
            # Add the second half of a two-line course title
            if course_match_end:
                course_title2, course_credit = course_match_end.groups()
                course_title = course_title1.strip() + ' ' + course_title2.strip()
                current_course = create_new_course(course_name, course_title, course_credit)
                courses.append(current_course)
                start_course = False
                add_description = True

        elif course_match:
            # If we find a course line, extract information and start a new course
            course_name, course_title, course_credit = course_match.groups()
            current_course = create_new_course(course_name, course_title, course_credit)
            courses.append(current_course)
            start_course = False
            add_description = True

        elif course_match_start:
            course_name, course_title1 = course_match_start.groups()
            start_course = True                    
            
        elif current_course is not None:
            # If we are in the middle of a course, add the line to its description
            if add_description:
                # When the description ends, parse it to fill in prerequisites, 
                # recommended, warnings, and substitutions
                if line == '':
                    add_description = False
                    current_course = update_description(course=current_course)
                else:
                    current_course['description'] += line + '\n'

    return courses

# %% [markdown]
# ## Read in raw file

# %%
infile = 'tmp_pdf2txt.txt'
with open(infile, 'r') as file:
    # Read the entire content of the file into a string
    text = file.read()
    
courses = parse_course_info(text)

# %% [markdown]
# ### Look at the courses

# %%
# Create a dictionary with name as the key
classes = {course['name']: course for course in courses}

# %%
classes['CAPL 398A']['prerequisites']
# Out:
# ''

# %%
classes['WRTG 394']['prerequisites']
# Out:
# 'WRTG 112 or equivalent'

# %% [markdown]
# #### Editing the course prerequisites to make automation easier
#
# - Adding a field ['done'] to exclude while editing

# %%
class_template = r'([A-Z]{3}[A-Z]? \d{3}[A-Z]?)'
A = class_template

singleton = re.compile(f'^{A}$')

course_or_list2 = re.compile(f'^{A} or {A}$')
course_or_list3 = re.compile(f'^{A}, {A}, or {A}$')
course_or_list4 = re.compile(f'^{A}, {A}, {A}, or {A}$')

course_and_list2 = re.compile(f'^{A} and {A}$')
course_and_list3 = re.compile(f'^{A}, {A}, and {A}$')
course_and_list4 = re.compile(f'^{A}, {A}, {A}, and {A}$')

# %%
def mark_done(class_info, pattern=singleton):
    # Mark classes with prerequisites done so we don't iterate over them anymore
    prerequisites_text = class_info['prerequisites']
    match = pattern.search(prerequisites_text)

    if prerequisites_text == '':
        class_info['pre']  = ''
        class_info['done'] = 1
    elif match:
        class_info['pre']  = prerequisites_text
        class_info['done'] = 1
    else:
        class_info['pre']  = ''
        class_info['done'] = 0

# %%
def mark_all_done(classes, pattern=singleton):
    # Mark classes with prerequisites done so we don't iterate over them anymore

    for class_name, class_info in classes.items():
        prerequisites_text = class_info['prerequisites']
        match = pattern.search(prerequisites_text)

        if prerequisites_text == '':
            class_info['pre']  = ''
            class_info['done'] = 1
        elif match:
            class_info['pre']  = prerequisites_text
            class_info['done'] = 1
        else:
            class_info['pre']  = ''
            class_info['done'] = 0

    return classes

# %%
def update_prerequisites(class_info, pattern, type='or'):
    prerequisites_text = class_info['prerequisites']
    match = pattern.search(prerequisites_text)
    if match:
        groups = match.groups()
        if type == 'or': 
            replaced_text = f'({ " | ".join(groups) })'
        elif type == 'and':
            replaced_text = f'({ " & ".join(groups) })'
        class_info['pre'] = replaced_text
        class_info['done'] = 1

# %%
classes = mark_all_done(classes, pattern = singleton)

# %%
for class_name, class_info in classes.items():
    print(class_name + ':') 
    print(class_info.pre)
# Out:
# ACCT 220:
# {'name': 'ACCT 220', 'title': 'Principles of Accounting I', 'credit': '3', 'description': 'An introduction to the basic theory and techniques of contem-\nporary financial accounting. The objective is to identify the \nfundamental principles of accounting, identify and analyze \nbusiness transactions, prepare financial statements, and com-\nmunicate this information to users with different needs. Topics \ninclude the accounting cycle, transactions, and the preparation \nof financial statements for single-owner business organizations \nthat operate as service companies or merchandisers. Students \nmay receive credit for only one of the following courses: ACCT \n220 or BMGT 220.\n', 'prerequisites': '', 'recommended': '', 'warnings': '', 'substitutions': 'ACCT 220 or BMGT 220', 'done': 1, 'pre': ''}
# ACCT 221:
# {'name': 'ACCT 221', 'title': 'Principles of Accounting II', 'credit': '3', 'description': 'Prerequisite: ACCT 220. Further study of contemporary account-\ning practices, with an emphasis on data analysis for financial \nand managerial accounting. The goal is to analyze business \ntransactions, define the characteristics of business entities, \nexplain the interdependency of financial statements, employ \nmanagerial accounting techniques, and communicate this infor-\nmation to users with unique needs. Financial accounting topics \ninclude liabilities, equities, investments, and business entities. \nManagerial accounting topics include job order and process \ncosting, cost-volume-profit analysis, and budgets. Students  \nmay receive credit for only one of the following courses: ACCT \n221 or BMGT 221.\n', 'prerequisites': 'ACCT 220', 'recommended': '', 'warnings': '', 'substitutions': 'ACCT 221 or BMGT 221', 'done': 1, 'pre': 'ACCT 220'}
# ACCT 301:
# {'name': 'ACCT 301', 'title': 'Accounting for Nonaccounting Managers', 'credit': '3', 'description': '(May not be applied toward a major in accounting.) A survey of \naccounting principles relevant to making business decisions \nbased on financial information. The aim is to apply critical- \nthinking skills and ethical principles to accounting issues.  \nTopics include internal controls, financial reporting, financial \nstatements analysis, managerial accounting, and budgeting  \nelements. Students may receive credit for only one of the  \nfollowing courses: ACCT 301, MGMT 301, or MGST 301.\n', 'prerequisites': '', 'recommended': '', 'warnings': 'May not be applied toward a major in accounting.', 'substitutions': 'ACCT 301, MGMT 301, or MGST 301', 'done': 1, 'pre': ''}
# ACCT 310:
# {'name': 'ACCT 310', 'title': 'Intermediate Accounting I', 'credit': '3', 'description': '(Students should be cautious about enrolling in ACCT 310 or \nACCT 311. These are professional courses requiring intensive \nstudy and analysis and are not to be undertaken casually. Stu-\ndents who have not taken ACCT 221 within the last two years \nmay have difficulty.) Prerequisite: ACCT 221. A comprehensive \nanalysis of financial accounting topics related to preparing finan-\ncial statements for external reporting. The objective is to analyze \ncomplex business transactions and their impact on financial \nstatements. Focus is on researching and analyzing emerging \nissues in accounting, business transactions, and financing. Stu-\ndents may receive credit for only one of the following courses: \nACCT 310 or BMGT 310.\n', 'prerequisites': 'ACCT 221', 'recommended': '', 'warnings': 'Students should be cautious about enrolling in ACCT 310 or ACCT 311. These are professional courses requiring intensive study and analysis and are not to be undertaken casually. Stu-dents who have not taken ACCT 221 within the last two years may have difficulty.', 'substitutions': 'ACCT 310 or BMGT 310', 'done': 1, 'pre': 'ACCT 221'}
# ACCT 311:
# {'name': 'ACCT 311', 'title': 'Intermediate Accounting II', 'credit': '3', 'description': '(A continuation of ACCT 310. Students should be cautious about \nenrolling in ACCT 310 or ACCT 311. These are professional \ncourses requiring intensive study and analysis and are not to \nbe undertaken casually. Students who have not taken ACCT 310 \nwithin the last two years may have difficulty.) Prerequisite: ACCT \n310. A comprehensive analysis of financial accounting top-\nics, including preparation of financial statements and external \nreports. The aim is to analyze complex business transactions \nand their impact on financial statements. Focus is on research-\ning and analyzing emerging issues in accounting, business \ntransactions, and financing. Students may receive credit for  \nonly one of the following courses: ACCT 311 or BMGT 311.\n', 'prerequisites': 'ACCT 310', 'recommended': '', 'warnings': 'A continuation of ACCT 310. Students should be cautious about enrolling in ACCT 310 or ACCT 311. These are professional courses requiring intensive study and analysis and are not to be undertaken casually. Students who have not taken ACCT 310 within the last two years may have difficulty.', 'substitutions': 'ACCT 311 or BMGT 311', 'done': 1, 'pre': 'ACCT 310'}
# ACCT 320:
# {'name': 'ACCT 320', 'title': 'Fraud Detection and Deterrence', 'credit': '3', 'description': 'Prerequisite: ACCT 220 or ACCT 301. A study of the principles \nbehind and standards for examining, identifying, detecting, \nand deterring fraud. The objective is to differentiate types of \nfraud, assess organizational characteristics conducive to fraud, \nand develop a plan to detect and deter fraud. Topics include \nthe fraud triangle, cash larceny, check tampering, skimming, \nregister disbursement schemes, cash receipts schemes, billing \nschemes, payroll and expense reimbursement issues, asset \nmisappropriations, corruption, accounting principles and fraud, \nfraudulent financial statements, whistleblowing, interviewing \nwitnesses, and writing reports. Focus is on creating and com-\nmunicating meaningful data visualizations for stakeholders.\n', 'prerequisites': '(ACCT 220 | ACCT 301)', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 0}
# ACCT 321:
# {'name': 'ACCT 321', 'title': 'Cost Accounting Data Analytics', 'credit': '3', 'description': 'Prerequisite: ACCT 221. A study of basic cost accounting con-\ncepts. The goal is to apply basic cost accounting concepts,  \nuse technology to prepare financial deliverables, evaluate  \nbusiness and financial data, and communicate financial infor-\nmation. Topics include ethics, corporate social responsibility, \nand the evaluation of business and financial data to make  \nprofit-maximizing decisions. Discussion also covers the role of  \naccountants in decision-making; cost behavior; cost planning and \ncontrol; and costing methods, such as standard costing, budget-\ning, and inventory valuation. Focus is on using data analytics and \ncreating and communicating meaningful data visualizations  \nfor decision-making. \n', 'prerequisites': 'ACCT 221', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': 'ACCT 221'}
# ACCT 323:
# {'name': 'ACCT 323', 'title': 'Federal Income Tax I', 'credit': '3', 'description': 'Prerequisite: ACCT 220 or FINC 321. A study of data and \nprocesses related to the preparation of federal income tax for \nindividuals and other entities. The objective is to explain the leg-\nislative process, conduct tax research, evaluate tax implications, \nand complete an individual tax return. Topics include the legisla-\ntive process, tax policy, research, and the evaluation of transac-\ntions and decisions for planning and compliance. Emphasis is \non ethics and professional responsibilities.\n', 'prerequisites': '(ACCT 220 | FINC 321)', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 0}
# ACCT 417:
# {'name': 'ACCT 417', 'title': 'Federal Income Tax II', 'credit': '3', 'description': '(Strongly recommended for students seeking careers as CPAs.) \nPrerequisites: ACCT 311 and ACCT 323. A continuing study \nof federal income taxation as applied to different business \nentities, including corporations, flow-through entities, estates, \nand trusts. The aim is to analyze tax planning and compli-\nance issues; conduct tax research; and analyze, evaluate, and \ncommunicate tax implications and data. Discussion covers tax \nresearch, planning, procedure, compliance, ethics, and profes-\nsional responsibility. Topics also include the tax implications of \nvarious entities’ financial and business decisions and transac-\ntions. Students may receive credit for only one of the following \ncourses: ACCT 417 or BMGT 417.\n', 'prerequisites': '(ACCT 311 & ACCT 323)', 'recommended': '', 'warnings': 'Strongly recommended for students seeking careers as CPAs.', 'substitutions': 'ACCT 417 or BMGT 417', 'done': 0}
# ACCT 422:
# {'name': 'ACCT 422', 'title': 'Auditing Theory and Practice', 'credit': '3', 'description': 'Prerequisite: ACCT 311. Recommended: ACCT 326. A study of \nthe auditing profession, audit process, and other assurance and \nnon-assurance services related to the CPA profession. The objec-\ntive is to design an audit plan, apply audit procedures, evaluate \naudit findings, and assess the impact of standards and emerging \nissues. Topics include generally accepted auditing standards, \ntests of controls and substantive tests, statistical sampling, \ndata analytics, report forms, and opinions. Various techniques \nare used to study auditing concepts and practices; these may \ninclude the use of problem sets, case studies, computer applica-\ntions, and other materials. Students may receive credit for only \none of the following courses: ACCT 422 or BMGT 422.\n', 'prerequisites': 'ACCT 311', 'recommended': 'ACCT 326', 'warnings': '', 'substitutions': 'ACCT 422 or BMGT 422', 'done': 1, 'pre': 'ACCT 311'}
# ACCT 424:
# {'name': 'ACCT 424', 'title': 'Advanced Accounting', 'credit': '3', 'description': 'Prerequisite: ACCT 311. A study of advanced accounting theory, \napplied to specialized topics and contemporary problems. The \naim is to prepare, present, and explain financial statements in \nfive sectors—consolidated, international, partnership, not-for-\nprofit, and state and local governments—and analyze a firm’s \ndissolution or reorganization. Emphasis is on consolidated \nstatements and partnership accounting. Various techniques are \nused to study accounting theory and practice; these may include \nthe use of data analytics, problem sets, case studies, computer \napplications, and other materials. Students may receive credit \nfor only one of the following courses: ACCT 424 or BMGT 424.\n', 'prerequisites': 'ACCT 311', 'recommended': '', 'warnings': '', 'substitutions': 'ACCT 424 or BMGT 424', 'done': 1, 'pre': 'ACCT 311'}
# ACCT 326:
# {'name': 'ACCT 326', 'title': 'Accounting Information Systems', 'credit': '3', 'description': 'Prerequisite: ACCT 221. An introduction to accounting informa-\ntion systems (AIS) concepts. The objective is to evaluate how \nAIS tools are used to record, process, and analyze financial data; \ndetermine how best to integrate AIS tools and processes in a \ngiven organization; review and recommend controls to secure AIS  \napplications and processes; and evaluate how technology can be \nused in AIS applications. Topics include transactional processing \nconcepts and core AIS transactional cycles, basic control frame-\nworks used to secure AIS applications and processes, strategies \nfor implementing or upgrading AIS applications, information \ntechnology and accounting standards, and e-commerce and \ne-business. Students may receive credit for only one of the  \nfollowing courses: ACCT 326, BMGT 320, or BMGT 326.\n', 'prerequisites': 'ACCT 221', 'recommended': '', 'warnings': '', 'substitutions': 'ACCT 326, BMGT 320, or BMGT 326', 'done': 1, 'pre': 'ACCT 221'}
# ACCT 350:
# {'name': 'ACCT 350', 'title': 'Federal Financial Management', 'credit': '3', 'description': 'Prerequisite: ACCT 220 or ACCT 301. Analysis and discussion \nof issues relating to federal financial management. The objec-\ntive is to apply knowledge of the federal process to accounting \npractice, administer federal grants and contracts, and research \nfederal laws and regulations. Topics include the CFO Act, the \nfederal budget, federal contracts and grants, data visualization \npresentations, and federal financial and information systems. \nDiscussion also covers detection and deterrence of fraud, \nwaste, and abuse.\n', 'prerequisites': '(ACCT 220 | ACCT 301)', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 0}
# ACCT 410:
# {'name': 'ACCT 410', 'title': 'Accounting for Government and Not-for-Profit Organizations', 'credit': '3', 'description': 'Prerequisite: ACCT 310. An introduction to the theory and \npractice of accounting as applied to governmental entities and \nnot-for-profit organizations. The objective is to evaluate transac-\ntions, prepare and analyze financial statements, write financial \nbriefings, prepare data visualization presentations, and apply \naccounting rules and procedures. Topics include the evaluation \nand preparation of reports required for governmental and not-\nfor-profit entities. Students may receive credit for only one of \nthe following courses: ACCT 410 or BMGT 410.\n', 'prerequisites': 'ACCT 310', 'recommended': '', 'warnings': '', 'substitutions': 'ACCT 410 or BMGT 410', 'done': 1, 'pre': 'ACCT 310'}
# ACCT 411:
# {'name': 'ACCT 411', 'title': 'Ethics and Professionalism in Accounting', 'credit': '3', 'description': 'Prerequisite: ACCT 311. An examination of ethical behavior in \norganizations and for the accounting and auditing professions. \nThe goal is to identify ethical dilemmas, research regulations, \nand apply problem-solving methodology to resolve unethical \nsituations. Discussion covers the AICPA Code of Professional \nConduct and the ethical codes and requirements of other \nstandard-setting organizations. Corporate governance, sustain-\nability, and legal and regulatory obligations are explored within \nan ethical framework, including philosophical models and \nethical theories, as well as within environmental, social, and \ngovernance (ESG) criteria.\n', 'prerequisites': 'ACCT 311', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': 'ACCT 311'}
# ACCT 452:
# {'name': 'ACCT 452', 'title': 'Federal Auditing', 'credit': '3', 'description': 'Prerequisite: ACCT 221. An overview of the federal auditing life \ncycle. The objective is to plan, manage, and execute a federal \naudit; identify and evaluate the program and financial risks; \nand identify and recommend enhancements to operations \nand technology. Topics include federal audits; data visualiza-\ntion, communicating audit findings to stakeholders, providing \nadvisory support, and evaluating program and financial risks; \nmanaging technology and increasing economy and efficiency; \nand minimizing fraud, waste, and abuse. Discussions also cover \nthe auditing of grants and contracts.\n', 'prerequisites': 'ACCT 221', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': 'ACCT 221'}
# ACCT 486A:
# {'name': 'ACCT 486A', 'title': 'Workplace Learning in Accounting', 'credit': '3', 'description': 'Prerequisites: 9 credits in the discipline and prior program \napproval (requirements detailed online at umgc.edu/wkpl). The \nintegration of discipline-specific knowledge with new experi-\nences in the work environment. Tasks include completing a \nseries of academic assignments that parallel work experiences.\n', 'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 0}
# ACCT 486B:
# {'name': 'ACCT 486B', 'title': 'Workplace Learning in Accounting', 'credit': '6', 'description': 'Prerequisites: 9 credits in the discipline and prior program \napproval (requirements detailed online at umgc.edu/wkpl). The \nintegration of discipline-specific knowledge with new experi-\nences in the work environment. Tasks include completing a \nseries of academic assignments that parallel work experiences.\n', 'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 0}
# AASP 201:
# {'name': 'AASP 201', 'title': 'Introduction to African American Studies', 'credit': '3', 'description': '(Fulfills the general education requirement in behavioral and \nsocial sciences.) An interdisciplinary study of significant aspects \nof African American history and culture, emphasizing the devel-\nopment of African American communities from the Middle Pas-\nsage to the present. The objective is to conduct research, apply \ncritical-thinking skills, and articulate diverse historical perspec-\ntives in the context of African American history and culture. Top-\nics include definitions of African American identity, influences, \nand achievements within American culture, as well as issues \nconfronting African Americans. Students may receive credit for \nonly one of the following courses: AASP 100 or AASP 201.\n', 'prerequisites': '', 'recommended': '', 'warnings': 'Fulfills the general education requirement in behavioral and social sciences.', 'substitutions': 'AASP 100 or AASP 201', 'done': 1, 'pre': ''}
# ACCT 425:
# {'name': 'ACCT 425', 'title': 'International Accounting', 'credit': '3', 'description': 'Prerequisite: ACCT 311. A study of accounting in a multinational \ncontext covering historical developments and international \nfinancial reporting standards. The objective is to recognize the \ninfluence of politics and culture on the development of account-\ning systems, prepare financial statements according to inter- \nnational financial reporting standards, and analyze the financial \nstatements of a multinational enterprise. Strategies to manage \nand hedge against foreign currency exposure are developed. \nTopics include sustainability, foreign exchange and taxation, \nintercompany transfer pricing, data analytics, and emerging \nissues in international accounting. Students may receive credit \nfor only one of the following courses: ACCT 425 or ACCT 498A.\n', 'prerequisites': 'ACCT 311', 'recommended': '', 'warnings': '', 'substitutions': 'ACCT 425 or ACCT 498A', 'done': 1, 'pre': 'ACCT 311'}
# ACCT 436:
# {'name': 'ACCT 436', 'title': 'Internal Auditing', 'credit': '3', 'description': '(Designed to align with the standards of the Institute of Internal \nAuditors and help prepare for the Certified Internal Auditor exam-\nination.) Prerequisite: ACCT 311. An exploration of the consulta-\ntive role in the management of risk. The aim is to identify the \nstandards that apply to internal auditors, audit processes, and \nprocedures and to assess internal control deficiencies. Topics \ninclude internal auditing standards, scope, responsibilities, eth-\nics, controls, techniques, and reporting practices. Data analytics \nand practice involve the use of software such as Excel, Power BI, \nTableau, ACL, and IDEA. Students may receive credit for only one \nof the following courses: ACCT 436, ACCT 498E, or BMGT 498E.\n', 'prerequisites': 'ACCT 311', 'recommended': '', 'warnings': 'Designed to align with the standards of the Institute of Internal Auditors and help prepare for the Certified Internal Auditor exam-ination.', 'substitutions': 'ACCT 436, ACCT 498E, or BMGT 498E', 'done': 1, 'pre': 'ACCT 311'}
# ACCT 438:
# {'name': 'ACCT 438', 'title': 'Fraud and Forensic Accounting', 'credit': '3', 'description': 'Prerequisite: ACCT 311. An analysis and discussion of issues \nrelating to fraud and forensic accounting. The objective is to \nidentify the resources for detecting fraud, evaluate the condi-\ntions that encourage fraud, and design effective fraud detection \nand deterrence plans. Discussion covers the principles and \nstandards for proactive and reactive investigation, as well as \ndetection and control of fraud. Focus is on data analytics and \ncreating and communicating meaningful data visualizations  \nfor stakeholders from the perspective of public, internal, and \nprivate accountants.\n', 'prerequisites': 'ACCT 311', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': 'ACCT 311'}
# ACCT 440:
# {'name': 'ACCT 440', 'title': 'Forensic and Investigative Accounting', 'credit': '3', 'description': 'Prerequisite: ACCT 320 or ACCT 438. An analysis and discus-\nsion of issues relating to forensic and investigative account-\ning. The goal is to research and describe the use of forensic \naccounting evidence, identify the role of the forensic accoun-\ntant, apply investigative and forensic accounting practices, and \npresent forensic accounting evidence as an expert witness. \nForensic and investigative methods, including the use of data \nanalytics, auditing, and technology are demonstrated. Topics \ninclude criminal and civil litigation support, rules of evidence, \nand accreditation of expert witnesses.\n', 'prerequisites': '(ACCT 320 | ACCT 438)', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 0}
# ANTH 101:
# {'name': 'ANTH 101', 'title': 'Introduction to Biological Anthropology', 'credit': '3', 'description': 'A survey of general patterns in the development of human \nculture, addressing the biological and morphological aspects \nof humans viewed in their cultural setting. The aim is to apply \nanthropological knowledge to understanding human origins and \nhow human populations adapt to the environment. Discussion \nexamines human evolution and adaptation, including biocultural \npatterns in humans and other primates. Students who complete \nboth ANTH 101 and ANTH 102 may not receive credit for ANTH \n340, BEHS 340, or BEHS 341.\n', 'prerequisites': '', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': ''}
# ANTH 102:
# {'name': 'ANTH 102', 'title': 'Introduction to Cultural Anthropology', 'credit': '3', 'description': 'A survey of social and cultural principles inherent in ethno-\ngraphic descriptions. The objective is to apply anthropological \nknowledge of human behavior to everyday situations and prob-\nlems. Students who complete both ANTH 101 and ANTH 102 \nmay not receive credit for ANTH 340, BEHS 340, or BEHS 341.\n', 'prerequisites': '', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': ''}
# ANTH 298:
# {'name': 'ANTH 298', 'title': 'Special Topics in Anthropology', 'credit': '1–3', 'description': 'A presentation of anthropological perspectives on selected top-\nics of broad general interest. May be repeated to a maximum of \n6 credits when topics differ.\n', 'prerequisites': '', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': ''}
# ANTH 345:
# {'name': 'ANTH 345', 'title': 'World Prehistory and Archaeology', 'credit': '3', 'description': 'An intermediate-level exploration of world prehistory and \narchaeology. The goal is to analyze the cultural, technological, \nand subsistence patterns of prehistoric humans and relate \nthese patterns to contemporary human societies and popula-\ntions. Discussion covers archaeological theories and methods; \nsubsistence strategies; and the applications of archaeological \nknowledge to modern community, regional, and global issues.\n', 'prerequisites': '', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': ''}
# ANTH 346:
# {'name': 'ANTH 346', 'title': 'Anthropology of Language and Communication', 'credit': '3', 'description': 'An intermediate-level anthropological study of language, com-\nmunication, and culture. The aim is to understand language in \na cultural context; assess how the concepts, approaches, and \nmethods of linguistic anthropology explain communication in \nchanging cultural environments; and recognize how language \nboth shapes and is shaped by culture. Topics include the origin \nof human language, linguistic diversity, structural elements \nof verbal and nonverbal language, language as social action, \nresearch in anthropological linguistics, language and power \nhierarchies, gendered communications, and linguistic diversity \nin the contemporary world.\n', 'prerequisites': '', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': ''}
# ANTH 350:
# {'name': 'ANTH 350', 'title': 'Health, Illness, and Healing', 'credit': '3', 'description': 'Recommended: ANTH 102. An overview of health, illness, and \nhealing from a cross-cultural perspective. The objective is to \napply the perspectives of medical anthropology to promote indi-\nvidual and public health in local, national, and global contexts. \nTopics include cultural and social influences on health and heal-\ning, the experience and meaning of illness, and current issues in \npublic and global health.\n', 'prerequisites': '', 'recommended': 'ANTH 102', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': ''}
# ANTH 351:
# {'name': 'ANTH 351', 'title': 'Anthropology in Forensic Investigations', 'credit': '3', 'description': 'An overview of forensic anthropology, an applied field of anthro-\npology that seeks to recover, identify, and evaluate human skel-\netal remains within a medicolegal context. The aim is to explore \nthe processes and methods used by forensic anthropologists to \nidentify a cause and manner of death and determine an approxi-\nmate postmortem interval. Topics include the forensic context, \nthe human skeletal system, methods of identification, cause \nand manner of death, assessment of trauma, and analysis of \nevidence to draw conclusions about a case.\n', 'prerequisites': '', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': ''}
# ANTH 398:
# {'name': 'ANTH 398', 'title': 'Intermediate Special Topics in Anthropology', 'credit': '1–3', 'description': 'A presentation of anthropological perspectives on selected top-\nics of broad general interest. May be repeated to a maximum of \n6 credits when topics differ.\n', 'prerequisites': '', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': ''}
# ANTH 417:
# {'name': 'ANTH 417', 'title': 'Peoples and Cultures of East Asia', 'credit': '3', 'description': 'An advanced anthropological study of the peoples and cultures \nof East Asia, focusing on China, Japan, and Korea. The aim is \nto apply anthropological theories and methods to the inter-\npretation of contemporary East Asian cultures, relate family \nstructure to individual choices and social interactions in East \nAsian cultures, and analyze how ethnic and national identities \nand regional differences affect regional and global interactions. \nTopics include urbanization, social values, social change, and \nthe role of East Asia in the modern world.\n', 'prerequisites': '', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': ''}
# APTC 495:
# {'name': 'APTC 495', 'title': 'Applied Technology Capstone', 'credit': '3', 'description': 'Prerequisites: 27 credits in major coursework. A project-based \napplication of computing knowledge and skills to solve prob-\nlems. Focus is on researching, planning, and implementing  \na computing-based solution to an approved business and  \ndisciplinary-based problem outside the primary area of tech- \nnology or computing focus. Assignments include working in \nteams through the planning, analysis, design, implementa-\ntion, testing, and documentation phases. A presentation of the \napplied solutions constitutes a final learning demonstration.\n', 'prerequisites': '27 credits in major coursework', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 0}
# ARAB 111:
# {'name': 'ARAB 111', 'title': 'Elementary Arabic I', 'credit': '3', 'description': 'For online sections, microphone, speakers, and occasional \nsynchronous work required. (Not open to native speakers of Ara-\nbic; assumes no prior knowledge of Arabic. Students with prior \nexperience with the Arabic language should take a placement \ntest to assess appropriate level.) An introduction to spoken \nand written modern standard Arabic. The objective is to com-\nmunicate in Arabic in some concrete, real-life situations, using \nculturally appropriate language and etiquette. Ample practice \nin Arabic pronunciation and the structures needed for everyday \ncommunication are provided.\n', 'prerequisites': '', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': ''}
# ARAB 112:
# {'name': 'ARAB 112', 'title': 'Elementary Arabic II', 'credit': '3', 'description': 'For online sections, microphone, speakers, and occasional \nsynchronous work required. (Not open to native speakers of \nArabic; assumes no prior knowledge of Arabic. Students with \nprior experience with the Arabic language should take a place-\nment test to assess appropriate level.) Prerequisite: ARAB 111 \nor appropriate score on a placement test. An introduction to \nspoken and written modern standard Arabic. The objective is \nto communicate in Arabic in some concrete, real-life situations, \nusing culturally appropriate language and etiquette. Ample \npractice in Arabic pronunciation and the structures needed for \neveryday communication are provided.\n', 'prerequisites': 'ARAB 111 or appropriate score on a placement test', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 0}
# ARAB 114:
# {'name': 'ARAB 114', 'title': 'Elementary Arabic III', 'credit': '3', 'description': 'For online sections, microphone, speakers, and occasional  \nsynchronous work required. (Not open to native speakers  \nof Arabic.) Prerequisite: ARAB 112 or appropriate score on a \nplacement test. Further development of skills in elementary \nspoken and written modern standard Arabic. The aim is to com-\nmunicate in Arabic in a variety of real-life situations, using cul-\nturally appropriate language. Practice is provided in improving \npronunciation and developing the oral and written skills used  \nin everyday communication.\n', 'prerequisites': 'ARAB 112 or appropriate score on a placement test', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 0}
# ARAB 115:
# {'name': 'ARAB 115', 'title': 'Elementary Arabic IV', 'credit': '3', 'description': 'For online sections, microphone, speakers, and occasional \nsynchronous work required. (Not open to native speakers of \nArabic.) Prerequisite: ARAB 114 or appropriate score on a place-\nment test. Further development of skills in elementary spoken \nand written modern standard Arabic. The objective is to interact \neffectively with native Arabic speakers in a variety of real-life \nsituations, using culturally appropriate language. Practice in \nfine-tuning pronunciation and applying language skills to a \nrange of contexts is provided.\n', 'prerequisites': 'ARAB 114 or appropriate score on a place-ment test', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 0}
# ARAB 333:
# {'name': 'ARAB 333', 'title': 'Middle Eastern Cultures', 'credit': '3', 'description': '(Conducted in English.) A project-driven and discussion-based \nstudy of Middle Eastern cultures. The aim is to demonstrate \ncultural competence by explaining and analyzing Middle East-\nern cultures through a variety of perspectives. Topics include \nreligion, cultural practices, history, geography, and societies of \nthe Middle East. Students may receive credit for only one of the \nfollowing courses: ARAB 333 or ARAB 334.\n', 'prerequisites': '', 'recommended': '', 'warnings': 'Conducted in English.', 'substitutions': 'ARAB 333 or ARAB 334', 'done': 1, 'pre': ''}
# ARTT 110:
# {'name': 'ARTT 110', 'title': 'Introduction to Drawing', 'credit': '3', 'description': 'A hands-on introduction to various drawing media and related \ntechniques. The objective is to translate the three-dimensional \nworld into two dimensions, communicate through a visual \nmedium, and critique visual works of art. Projects are based  \non nature and still life.\n', 'prerequisites': '', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': ''}
# ARTT 120:
# {'name': 'ARTT 120', 'title': 'Design I: Arrangement and Color', 'credit': '3', 'description': 'Prerequisite: GRCO 100. A project-driven study of the design ele-\nments of a composition as they relate to its overall expression. \nThe aim is to apply elements and principles of design, including \ncolor theory, to create a variety of compositions that effectively \ncommunicate ideas and emotions.\n', 'prerequisites': 'GRCO 100', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': 'GRCO 100'}
# ARTT 152:
# {'name': 'ARTT 152', 'title': 'Basics of Photography', 'credit': '3', 'description': '(Access to a digital camera with manual settings required.) An \nintroduction to basic photographic procedures with an empha-\nsis on composing, taking, and editing photographs. Discussion \ncovers the historical development of photography. Students \nmay receive credit for only one of the following courses:  \nARTT 152 or PHOT 198.\n', 'prerequisites': '', 'recommended': '', 'warnings': 'Access to a digital camera with manual settings required.', 'substitutions': 'ARTT 152 or PHOT 198', 'done': 1, 'pre': ''}
# ARTT 210:
# {'name': 'ARTT 210', 'title': 'Intermediate Drawing', 'credit': '3', 'description': 'Prerequisite: ARTT 110. A continuing examination of materials \nand techniques of drawing. The objective is to apply drawing \ntechniques and visual principles to various subjects, communi-\ncate through drawing, and critique works of art. More advanced \nmedia, compositions, techniques, and subjects are explored. \nStudents may receive credit for only one of the following \ncourses: ARTS 210 or ARTT 210.\n', 'prerequisites': 'ARTT 110', 'recommended': '', 'warnings': '', 'substitutions': 'ARTS 210 or ARTT 210', 'done': 1, 'pre': 'ARTT 110'}
# ARTT 320:
# {'name': 'ARTT 320', 'title': 'Painting', 'credit': '3', 'description': 'Prerequisite: ARTT 110. Practice in the basic tools and vocabu-\nlary of painting. The goal is to apply an understanding of com-\npositional strategies, visual principles, and basic materials  \nand techniques to produce paintings using oil/watercolor/\nacrylic paints.\n', 'prerequisites': 'ARTT 110', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': 'ARTT 110'}
# ARTT 428:
# {'name': 'ARTT 428', 'title': 'Advanced Painting', 'credit': '3', 'description': 'Prerequisite: ARTT 320. Creation of original compositions based \non the figure, nature, and still life, as well as expressive painting. \nThe goal is to paint in a variety of styles and techniques, work \nwith more complex forms (including drapery, transparency, and \nreflections), and work in landscape and/or figure in space paint-\ning. Emphasis is on the development of personal directions. \nMay be repeated to a maximum of 12 credits.\n', 'prerequisites': 'ARTT 320', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': 'ARTT 320'}
# ARTH 204:
# {'name': 'ARTH 204', 'title': 'Film and American Culture Studies', 'credit': '3', 'description': 'An introductory study of the relationship between film and \nAmerican culture. The objective is to improve one’s ability \nto understand a film’s message and to expand one’s cultural \nawareness. Discussion covers the way one of our most popular \nmedia portrays American culture and influences our interpreta-\ntion of cultural issues. Various films, filmmaking issues, and \nrepresentative filmmakers’ work are examined. Students may \nreceive credit for only one of the following courses: ARTH 204, \nAMST 204, or HUMN 204.\n', 'prerequisites': '', 'recommended': '', 'warnings': '', 'substitutions': 'ARTH 204, AMST 204, or HUMN 204', 'done': 1, 'pre': ''}
# ARTH 334:
# {'name': 'ARTH 334', 'title': 'Understanding Movies', 'credit': '3', 'description': '(Formerly HUMN 334.) An analysis of one of the most important \nmeans of artistic expression of the 20th century. The goal is to \nacquire a deeper understanding of the aesthetic qualities of film \nby considering the stylistic elements of film as it has evolved \nthroughout the century and weighing the special relationship \nbetween cinema and literature. Students may receive credit  \nfor only one of the following courses: ARTH 334, HUMN 334,  \nor HUMN 498D.\n', 'prerequisites': '', 'recommended': '', 'warnings': 'Formerly HUMN 334.', 'substitutions': 'ARTH 334, HUMN 334,  or HUMN 498D', 'done': 1, 'pre': ''}
# ARTH 372:
# {'name': 'ARTH 372', 'title': 'History of Western Art I', 'credit': '3', 'description': '(Formerly ARTH 370.) A survey of the development of the \nWestern tradition of visual art in its various forms that exam-\nines and compares the expression of cultural and aesthetic \nvalues in different parts of the Western world from prehistory \nthrough the Middle Ages. The objective is to apply principles of \nvisual literacy; describe, analyze, and contextualize content and \nelements of art; and differentiate historic periods and styles of \nart. Students may receive credit for only one of the following \ncourses: ARTH 370 or ARTH 372.\n', 'prerequisites': '', 'recommended': '', 'warnings': 'Formerly ARTH 370.', 'substitutions': 'ARTH 370 or ARTH 372', 'done': 1, 'pre': ''}
# ARTH 373:
# {'name': 'ARTH 373', 'title': 'History of Western Art II', 'credit': '3', 'description': '(Formerly ARTH 371.) A survey of the development of visual \nart of the Western world in its various forms that examines and \ncompares the expression of cultural and aesthetic values in \nEurope and the United States from 1300 to the present day. The \naim is to apply principles of visual literacy; describe, analyze, \nand contextualize content and elements of art; and differentiate \nhistoric periods and styles of art. Students may receive credit \nfor only one of the following courses: ARTH 371 or ARTH 373.\n', 'prerequisites': '', 'recommended': '', 'warnings': 'Formerly ARTH 371.', 'substitutions': 'ARTH 371 or ARTH 373', 'done': 1, 'pre': ''}
# ARTH 375:
# {'name': 'ARTH 375', 'title': 'History of Graphic Art', 'credit': '3', 'description': 'Recommended: ARTH 204. A survey of the development of \ngraphic design with an emphasis on the historical, technologi-\ncal, and sociological influences on the production of typography \nand the aesthetics of visual media. The aim is to recognize the \nphilosophy of graphic arts, identify various movements within \nthe field, and analyze the impact of graphic arts on society.  \nTopics include major works and artists and cultural, social,  \nand religious movements and their impact on graphic arts.\n', 'prerequisites': '', 'recommended': 'ARTH 204', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': ''}
# ARTH 478:
# {'name': 'ARTH 478', 'title': 'History of Women in the Visual Arts', 'credit': '3', 'description': 'A survey of the work, roles, and representations of women in \nthe visual arts, from the 16th century to the present. The aim \nis to evaluate the role of women artists and assess the impact \nof gender on visual arts as a way to understand the complexity \nand diversity of human experience and culture. Emphasis is on \nwomen working in the tradition of Western art in painting, sculp-\nture, the decorative arts, performance art, photography, and other \nmedia and on how gender affected their art and their careers.\n', 'prerequisites': '', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': ''}
# ASTD 135:
# {'name': 'ASTD 135', 'title': 'Introduction to Japanese Language and Culture', 'credit': '3', 'description': '(Formerly JAPN 105. Not open to students with substantial \nprior experience with Japanese language or culture; assumes \nno prior knowledge of Japanese. Students with prior experience \nwith the Japanese language should take a placement test to \nassess appropriate level.) A hands-on, project-based introduc-\ntion to Japanese language and culture. The goal is to develop \ncultural competency and familiarity with the history, geography, \nand culture of Japan and to use basic language skills to func-\ntion effectively and appropriately in everyday life in Japan. Stu-\ndents may receive credit for only one of the following courses: \nASTD 135 or JAPN 105.\n', 'prerequisites': '', 'recommended': '', 'warnings': 'Formerly JAPN 105. Not open to students with substantial prior experience with Japanese language or culture; assumes no prior knowledge of Japanese. Students with prior experience with the Japanese language should take a placement test to assess appropriate level.', 'substitutions': 'ASTD 135 or JAPN 105', 'done': 1, 'pre': ''}
# ASTD 155:
# {'name': 'ASTD 155', 'title': 'Introduction to Korean Language and Culture', 'credit': '3', 'description': '(Not open to students with substantial prior experience with \nKorean language or culture; assumes no prior knowledge \nof Korean. Students with prior experience with the Korean \nlanguage should take a placement test to assess appropriate \nlevel.) A hands-on, project-based introduction to Korean lan-\nguage and culture. The goal is to develop cultural competence \nin personal interactions; demonstrate knowledge of the history, \ngeography, and culture of Korea; and use basic language skills \nto function effectively and appropriately in everyday activities in \nKorea. Students may receive credit for only one of the following \ncourses: ASTD 155 or KORN 105.\n', 'prerequisites': '', 'recommended': '', 'warnings': 'Not open to students with substantial prior experience with Korean language or culture; assumes no prior knowledge of Korean. Students with prior experience with the Korean language should take a placement test to assess appropriate level.', 'substitutions': 'ASTD 155 or KORN 105', 'done': 1, 'pre': ''}
# ASTD 284:
# {'name': 'ASTD 284', 'title': 'Foundations of East Asian Civilization', 'credit': '3', 'description': '(Formerly HIST 284.) An interdisciplinary survey of the foun-\ndations of East Asian civilization from its beginnings to the  \n17th century. The goal is to analyze philosophical, religious, \nartistic, economic, and political aspects of the region’s historical \nexperience. Focus is on China, Korea, and Japan. Topics include \nEast Asian belief systems (including Confucianism and Bud-\ndhism), the dynastic cycle, relations between steppe and agrar-\nian societies, warrior and scholar-gentry cultures, technological \nchange and economic development, and the role of class and \ngender in early East Asian society. Students may receive credit \nfor only one of the following courses: ASTD 150, ASTD 284,  \nor HIST 284.\n', 'prerequisites': '', 'recommended': '', 'warnings': 'Formerly HIST 284.', 'substitutions': 'ASTD 150, ASTD 284,  or HIST 284', 'done': 1, 'pre': ''}
# ASTD 285:
# {'name': 'ASTD 285', 'title': 'Introduction to Modern East Asia', 'credit': '3', 'description': '(Formerly HIST 285.) An interdisciplinary survey of East Asia \nfrom the late 17th century—beginning with Ming-Qing China, \nTokugawa Japan, and Choson Korea—to the present. The objec-\ntive is to trace how transformations on global, regional, and \nlocal levels led to the development of the modern nation-states \nof East Asia and to examine how those developments affected \nthe culture of the areas. Topics include the rise of imperial-\nism and colonialism; cross-cultural interactions; and issues of \ngender, class, and ethnicity in East Asian culture. Students may \nreceive credit for only one of the following courses: ASTD 160, \nASTD 285, or HIST 285.\n', 'prerequisites': '', 'recommended': '', 'warnings': 'Formerly HIST 285.', 'substitutions': 'ASTD 160, ASTD 285, or HIST 285', 'done': 1, 'pre': ''}
# ASTD 302:
# {'name': 'ASTD 302', 'title': 'The Two Koreas: Problems and Prospects', 'credit': '3', 'description': 'Prerequisite: Any writing course. Recommended: ASTD 284 \nor ASTD 285. A thematic study of the two Koreas from histori-\ncal, social, and foreign policy perspectives. The objective is to \nexamine scholarly viewpoints on key issues of Korean history \nand division; articulate key factors that shape U.S. and regional \npolicy toward North Korea; distinguish between different \nsources of information on the two Koreas; and interpret regional \ndevelopments based on knowledge of Korean issues. Topics \ninclude the “hermit kingdom” myth; liberation, division, and war; \nthe economic “miracle”; North Korean leadership; South and \nNorth Korean foreign relations; North Korea as a nuclear threat; \nand prospects for a unified Korea. Focus is on developing a \nstronger understanding of the two Koreas for practical and pro-\nfessional application. Assignments require research, analysis, \nand a written policy or strategy recommendation.\n', 'prerequisites': 'Any writing course', 'recommended': 'ASTD 284 or ASTD 285', 'warnings': '', 'substitutions': '', 'done': 0}
# ASTD 370:
# {'name': 'ASTD 370', 'title': 'Interpreting Contemporary China', 'credit': '3', 'description': 'Prerequisite: Any WRTG course. Recommended: ASTD 285. A \nthematic study of contemporary China from political, economic, \nsocial, and foreign policy perspectives. The objective is to iden-\ntify decision-making authorities, interpret major influences on \nthe Chinese economy, appraise the impact of grassroots social \nmovements, and distinguish factors that drive China’s foreign \npolicy. Focus is on developing engagement strategies for vari-\nous professional applications. Assignments require research, \nanalysis, and a written policy or strategy recommendation (e.g., \na policy paper or business strategy plan).\n', 'prerequisites': 'Any WRTG course', 'recommended': 'ASTD 285', 'warnings': '', 'substitutions': '', 'done': 0}
# ASTD 398:
# {'name': 'ASTD 398', 'title': 'Advanced Special Topics in Asian Studies', 'credit': '3', 'description': 'An investigation of a special topic, problem, or issue of particu-\nlar relevance to countries or peoples of the Pacific Rim or Indian \nOcean. Typical investigations include historical or contemporary \nsubjects focusing on cultural, economic, military, or political \nissues. Assignments include advanced reading and research.\n', 'prerequisites': '', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': ''}
# ASTD 485:
# {'name': 'ASTD 485', 'title': 'East Asian Studies Capstone ASTR 100 Introduction to Astronomy', 'credit': '3', 'description': 'Prerequisite: MATH 105, STAT 200, or a higher MATH or STAT \ncourse. An examination of the major areas of astronomy. Top-\nics include the solar system, stars and stellar evolution, and \ngalaxies. Current topics in astronomy are also discussed. The \nobjective is to use scientific and quantitative reasoning to make \ninformed decisions about topics related to space science. Stu-\ndents may receive credit for only one of the following courses: \nASTR 100, ASTR 101, ASTR 120, or GNSC 125.\n', 'prerequisites': 'MATH 105, STAT 200, or a higher MATH or STAT course', 'recommended': '', 'warnings': '', 'substitutions': 'ASTR 100, ASTR 101, ASTR 120, or GNSC 125', 'done': 0}
# BEHS 103:
# ...
# SWEN 647:
# {'name': 'SWEN 647', 'title': 'Software Verification and Validation', 'credit': '3', 'description': 'A study of methods for evaluating software for correctness, \nefficiency, performance, and reliability. Skills covered include pro-\ngram proving, code inspection, unit-level testing, and system-level \nanalysis. The difficulty and cost of some types of analysis and \nthe need for automation of tedious tasks are examined. Empha-\nsis is on problem-solving skills, especially in analyzing code.\n', 'prerequisites': '', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': ''}
# SWEN 651:
# {'name': 'SWEN 651', 'title': 'Usability Engineering', 'credit': '3', 'description': 'A study of the theory and practice of designing user interfaces \nfor interactive systems. Topics include the principles of usability \nengineering and basic rules for usable design. User interfaces \nare evaluated using techniques such as contextual inquiry, task \nanalysis, and usability testing. Discussion also covers when \nthese techniques are most appropriate.\n', 'prerequisites': '', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': ''}
# SWEN 656:
# {'name': 'SWEN 656', 'title': 'Advanced Software Design and Implementation', 'credit': '3', 'description': 'Prerequisite: SWEN 646. An exploration of software design and \nimplementation for reducing complexity of systems. Topics \ninclude software design patterns, object-oriented programming, \nand aspect-oriented programming design. Focus is on building \nsoftware products using these technologies.\n', 'prerequisites': 'SWEN 646', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': 'SWEN 646'}
# SWEN 661:
# {'name': 'SWEN 661', 'title': 'User Interface Implementation', 'credit': '3', 'description': 'Prerequisite: SWEN 651. An examination of all types of user \ninterfaces. Topics include developing user interfaces using \nmobile, desktop, and web technologies. Focus is on building \nuser interfaces using these technologies.\n', 'prerequisites': 'SWEN 651', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': 'SWEN 651'}
# SWEN 670:
# {'name': 'SWEN 670', 'title': 'Software Engineering Capstone', 'credit': '3', 'description': 'Prerequisite: 30 credits of program coursework, including all \ncore courses. A comprehensive examination of the tools, skills, \nand techniques of software engineering and their application. \nCompletion of a major team project is designed to integrate \nknowledge and skills gained through previous study and provide \nexperience of the constraints commonly experienced in industry \n(scheduling, vagueness of clients). Project requires forming \nteams (organization) and scheduling work to meet the deadlines \nimposed by the contract (syllabus).\n', 'prerequisites': '30 credits of program coursework, including all core courses', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 0}
# UCSP 615:
# {'name': 'UCSP 615', 'title': 'Orientation to Graduate Studies at UMGC (0) MSC 610 Foundations of Strategic Communications', 'credit': '6', 'description': 'Prerequisite: DCL 600M. Acquire foundational skills in strategic \ncommunications, including effective writing targeted to different \naudiences and media; fundamental research; and the planning, \nexecution, and assessment of a communications plan. Become \nfamiliar with the public relations, marketing, and advertising \nindustries and their practices; theoretical and ethical founda-\ntions; and the role of strategic communications in each.\n', 'prerequisites': 'DCL 600M', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': 'DCL 600M'}
# MSC 620:
# {'name': 'MSC 620', 'title': 'Communications Techniques and Tactics', 'credit': '6', 'description': 'Prerequisite: MSC 610. Develop internal and external com- \nmunications strategies and select and produce appropriate  \ncommunications tactics to execute them. Create internal com-\nmunications that focus on employee engagement, leadership, \nand change management. Exercise best practices in media  \nrelations and social media product development.\n', 'prerequisites': 'MSC 610', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': 'MSC 610'}
# MSC 630:
# {'name': 'MSC 630', 'title': 'Communications Leadership and Management', 'credit': '6', 'description': 'Prerequisite: MSC 620. Practice advanced strategic communi-\ncations decision-making in both national and international con-\ntexts. Coordinate public relations efforts internally, particularly \nbetween marketing and advertising departments. Master funda-\nmental financial accounting and budgeting concepts required \nfor many communications campaigns in business, government, \nand the nonprofit sectors. Align communications campaigns \nwith organizational objectives. Follow global strategic commu-\nnications trends and legal and ethical issues.\n', 'prerequisites': 'MSC 620', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': 'MSC 620'}
# MSC 640:
# {'name': 'MSC 640', 'title': 'Crisis Communications Management', 'credit': '6', 'description': 'Prerequisite: MSC 630. Develop strategic responses, including \ncrisis definition, issue management, and crisis communications \nmanagement, to crisis situations. Apply crisis communication \ntheory and implement risk communication and reputation and \nimage restoration best practices. Utilize appropriate research \nmethods to inform a crisis communications plan.\n', 'prerequisites': 'MSC 630', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': 'MSC 630'}
# MSC 670:
# {'name': 'MSC 670', 'title': 'Capstone: Communications Campaigns', 'credit': '6', 'description': 'Prerequisite: MSC 640. Assume the role of a corporate com-\nmunications director and create a communications plan to \nsupport an organizational strategy for an existing organization. \nConduct research; develop a problem statement; and identify \ncampaign goals and objectives, audience segments, and mes-\nsaging targeted to those segments. Create a communications \nstrategy with tactics and timelines, evaluation plans, and a \nrealistic budget.\n', 'prerequisites': 'MSC 640', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': 'MSC 640'}
# SYSE 610:
# {'name': 'SYSE 610', 'title': 'Systems Engineering Overview', 'credit': '3', 'description': 'An introduction to systems engineering using examples of man-\nufacturing, information, and mechanical systems that involve \nthe integration of different technologies. Emphasis is on the \nrole of the systems engineer. Systems thinking principles and \ncomplex systems and system-of-systems theory are reviewed. \nDiscussion covers various approaches to system dynamics \nmodeling. An overview of the system life cycle through con-\nception, design and development, integration and testing, and \ndeployment and support is provided.\n', 'prerequisites': '', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': ''}
# SYSE 620:
# {'name': 'SYSE 620', 'title': 'Requirements Engineering', 'credit': '3', 'description': 'An in-depth examination of the various techniques used in \nestablishing and specifying system requirements, both physical \nand functional. Topics include system decomposition, require-\nments traceability, configuration management, and require-\nments validation. Several U.S. and international standards  \nare examined as examples of requirements specification.\n', 'prerequisites': '', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': ''}
# SYSE 625:
# {'name': 'SYSE 625', 'title': 'Model-Based Systems Engineering', 'credit': '3', 'description': 'Prerequisite: SYSE 610. An introduction to formal system model-\ning and simulation methods using software-based approaches, \nwhich are replacing more traditional document-based descrip-\ntive modeling methods. Discussion covers the trend in industry \ntoward standardized modeling techniques using software,  \nespecially SysML (Systems Modeling Language) computer  \npackages, allowing greater consistency in system model repre-\nsentations between technologies, across industries, and even \nacross language barriers. Topics include ways that computers \ncan represent system models in detail and provide complex \nsystem simulations with minimum effort using several differ-\nent system modeling and simulation software platforms. The \nobjective is to be able to determine when and how model-based \nsystems engineering (MBSE) approaches are useful, which tools \nto use, and which data to use as input to the MBSE tools and \nhow to use the results from the tools in decision-making.\n', 'prerequisites': 'SYSE 610', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': 'SYSE 610'}
# SYSE 630:
# {'name': 'SYSE 630', 'title': 'System Design and Development', 'credit': '3', 'description': 'Prerequisites: SYSE 610 and SYSE 620. A detailed exploration \nof the design and development phases of the system life cycle. \nDiscussion covers several tools used for systems simulation \nand computer-aided design. Topics also include methods and \npolicies for change control and the principles of quality assur-\nance as an underlying concept in systems design.\n', 'prerequisites': '(SYSE 610 & SYSE 620)', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 0}
# SYSE 640:
# {'name': 'SYSE 640', 'title': 'System Integration and Test', 'credit': '3', 'description': 'Prerequisites: SYSE 610 and SYSE 620. A review of various \nstrategies used to integrate system components and verify \nsatisfaction of requirements at both subsystem and overall \nsystem levels. The concept of formal verification, validation, \nand accreditation (VV&A) is discussed. Examples of automated \nsoftware testing tools are also examined.\n', 'prerequisites': '(SYSE 610 & SYSE 620)', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 0}
# SYSE 650:
# {'name': 'SYSE 650', 'title': 'Design Considerations', 'credit': '3', 'description': 'Prerequisites: SYSE 610 and SYSE 620. An introduction to sys-\ntem engineering subdisciplines that are critical in system design \nand deployment. Discussion covers reliability, availability, and \nmaintainability (RAM) factors. Concepts in human factors engi-\nneering, system safety, and quality assurance are also reviewed.\n', 'prerequisites': '(SYSE 610 & SYSE 620)', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 0}
# SYSE 660:
# {'name': 'SYSE 660', 'title': 'Systems Engineering Management', 'credit': '3', 'description': 'Prerequisites: SYSE 630 and SYSE 640. An examination of \nthe role played by the systems engineer as liaison between \ntechnical specialists, business managers, and internal users or \nexternal customers. Discussion covers the traditional systems \ndevelopment life cycle, domestic and internal standards, and the \nevolving emphasis on agile methods and adaptive processes. \nTopics also include risk management and organizational consid-\nerations in outsourcing.\n', 'prerequisites': '(SYSE 630 & SYSE 640)', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 0}
# SYSE 670:
# {'name': 'SYSE 670', 'title': 'Systems Engineering Capstone', 'credit': '3', 'description': 'Prerequisites: SYSE 640 and SYSE 650. A project-based \ncapstone study of systems engineering designed to integrate \nknowledge and skills gained in previous study. Both individual \nprojects and a group project focus on demonstrating the ability \nto construct a system design and develop a plan for a system’s \ndevelopment and support.\n', 'prerequisites': '(SYSE 640 & SYSE 650)', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 0}
# TLP 610:
# {'name': 'TLP 610', 'title': 'Repositioning Your Leadership Skills', 'credit': '6', 'description': 'Prerequisite: DCL 600M. Master the ways in which leader-\nship takes place within organizations and the most effective \nleadership styles for directing individuals, projects, and groups \nto success. Demonstrate the differences between managing \nand leading, focusing on motivating and inspiring individuals \nin preparation for future challenges and opportunities. Explore \nthe various roles that leaders take on in domestic and global \nmarkets and the ways leaders influence events that can drive \nsuccess through individual and collaborative efforts. Create \nyour own personal brand as you begin a journey to becoming  \na transformational leader.\n', 'prerequisites': 'DCL 600M', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': 'DCL 600M'}
# TLP 620:
# {'name': 'TLP 620', 'title': 'Leading in the Organization', 'credit': '6', 'description': 'Prerequisite: TLP 610. Analyze the dynamics involved in leading \na workforce of multigenerational and diverse talent. Develop \nstrategies for facilitating an inclusive work culture and maximiz-\ning the varied skill sets and experiences of employees. Weigh \nthe impact of workforce change on organizations and consider \nthe potential challenges that run counter to respectful, civil, and \nethical work environments. Create retention and succession \nplanning strategies and techniques for coaching and mentoring \nemerging leaders.\n', 'prerequisites': 'TLP 610', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': 'TLP 610'}
# TLP 630:
# {'name': 'TLP 630', 'title': 'Leading with Strategy and Performance Measures', 'credit': '6', 'description': 'Prerequisite: TLP 620. Gain the tools to assess the organiza-\ntion’s bottom line and action steps for growth and sustainability. \nApply strategic management theories and practice to measure \nand motivate organizational performance, identify trends, \nand direct the different stages of the organization’s life cycle. \nBecome proficient using tools to review and interpret analytics, \nmarket research, and financial data that can drive short- and \nlong-range strategic decisions and identify potential deficien-\ncies that run counter to the organization’s mission and goals.\n', 'prerequisites': 'TLP 620', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': 'TLP 620'}
# TLP 640:
# {'name': 'TLP 640', 'title': 'Leading Through Change and Uncertainty', 'credit': '6', 'description': 'Prerequisite: TLP 630. Apply change management techniques \nfor leading and maintaining stability during unplanned, turbulent \nevents within the organization. Analyze and implement stra-\ntegic planning and decision-making approaches to diagnose \nthe symptoms and predictors of organizational challenges \nand obstacles to change. Use change management models to \nassess organizational performance and process reengineer-\ning and to forecast outcomes and resistance to change at the \nindividual, group, and organization levels.\n', 'prerequisites': 'TLP 630', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': 'TLP 630'}
# TLP 670:
# {'name': 'TLP 670', 'title': 'Leadership Capstone', 'credit': '6', 'description': 'Prerequisite: TLP 640. Lead a real-world consulting project.  \nApply the techniques of project management as you collabo- \nrate with a partnering organization to develop a strategic and \nfinancial plan to address an organizational issue. Use client- \nrelationship management, organizational diagnosis models,  \nand coaching and presentation skills to complete your consult-\ning project and showcase your solutions and plans to your \npartner organization.\n', 'prerequisites': 'TLP 640', 'recommended': '', 'warnings': '', 'substitutions': '', 'done': 1, 'pre': 'TLP 640'}

# %%
for class_name, class_info in classes.items():
    update_prerequisites(class_info, pattern = course_or_list2,  type = 'or')
    update_prerequisites(class_info, pattern = course_and_list2, type = 'and')
    update_prerequisites(class_info, pattern = course_or_list3,  type = 'or')
    update_prerequisites(class_info, pattern = course_and_list3, type = 'and')
    update_prerequisites(class_info, pattern = course_or_list4,  type = 'or')
    update_prerequisites(class_info, pattern = course_and_list4, type = 'and')

# %%
for class_name, class_info in classes.items():
    if class_info['done'] != True:
        print(class_name + ':', class_info['prerequisites'])
# Out:
# ACCT 320: (ACCT 220 | ACCT 301)
# ACCT 323: (ACCT 220 | FINC 321)
# ACCT 417: (ACCT 311 & ACCT 323)
# ACCT 350: (ACCT 220 | ACCT 301)
# ACCT 486A: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# ACCT 486B: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# ACCT 440: (ACCT 320 | ACCT 438)
# APTC 495: 27 credits in major coursework
# ARAB 112: ARAB 111 or appropriate score on a placement test
# ARAB 114: ARAB 112 or appropriate score on a placement test
# ARAB 115: ARAB 114 or appropriate score on a place-ment test
# ASTD 302: Any writing course
# ASTD 370: Any WRTG course
# ASTD 485: MATH 105, STAT 200, or a higher MATH or STAT course
# BEHS 300: (BEHS 210 & STAT 200)
# BEHS 486A: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# BEHS 486B: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# BEHS 495: BEHS 300 and completion of all requirements for the social science major
# BIOL 164: (BIOL 101 | BIOL 103 | BIOL 160)
# BIOL 230: BIOL 103 or other introductory biology course with laboratory
# BIOL 357: BIOL 325 or another upper-level biology course
# BIOL 362: (BIOL 101 | BIOL 103 | BIOL 160)
# BIOL 422: (BIOL 230 | BIOL 301 | BIOL 302 | BIOL 398G)
# BIOL 486A: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# BIOL 486B: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# BMGT 365: (BMGT 110 | BMGT 364)
# BMGT 485: BMGT 317, BMGT 364, BMGT 464 (or BMGT 465), and BMGT 484
# BMGT 486A: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# BMGT 486B: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# BMGT 495: BMGT 364, BMGT 365, FINC 330 (or BMGT 340), and MRKT 310
# CHEM 113: (CHEM 103 | CHEM 105)
# CHIN 112: CHIN 111 or appropriate score on a placement test
# CHIN 114: CHIN 112 or appropriate score on a placement test
# CHIN 115: CHIN 114 or appropriate score on a place-ment test
# COMM 300: WRTG 112 or equiva-lent
# COMM 202: WRTG 112 or equiva-lent
# COMM 302: (WRTG 112 | WRTG 101 | WRTG 101S)
# COMM 390: (WRTG 112 | WRTG 101 | WRTG 101S)
# COMM 400: WRTG 112 or equivalent
# COMM 480: (COMM 300 & COMM 302)
# COMM 486A: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# COMM 486B: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# COMM 492: WRTG 112 or equivalent
# COMM 495: COMM 300, COMM 302, and at least 9 additional credits of upper-level COMM, SPCH, and/or JOUR courses
# CMIT 265: CMIT 202 or CMSC 115 (or CMIS 141)
# CMIT 291: (CMIT 202 | CMIT 265)
# CMIT 320: CMIT 265 or CompTIA Network+ certification
# CMIT 380: (CMIT 202 & CMIT 320)
# CMIT 388: (CMIT 291 | CMIT 391)
# CMIT 420: (CMIT 320 & CMIT 382)
# CMIT 422: (CMIT 320 & CMIT 382)
# CMIT 424: CMIT 202 (or CompTIA A+ certification), CMIT 320 (or CompTIA Security+ certification), and CCJS 321
# CMIT 455: (CMIT 350 | CMIT 352)
# CMIT 460: (CMIT 320 & CMIT 424)
# CMIT 486A: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# CMIT 486B: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# CMIT 495: Completion of at least 27 credits of CMIT course-work
# CMSC 115: CMSC 105 (or CMIS 102)
# CMSC 215: CMSC 115 (or CMIS 141)
# CMSC 310: CMSC 115 (or CMIS 141)
# CMSC 315: CMSC 215 (or CMIS 242)
# CMSC 320: CMSC 115 (or CMIS 141)
# CMSC 325: CMSC 215 (or CMIS 242)
# CMSC 330: CMSC 315 (or CMSC 350)
# CMSC 335: CMSC 315 (or CMSC 350)
# CMSC 340: (CMSC 115 | CMIS 141)
# CMSC 345: CMSC 115 (or CMIS 141)
# CMSC 405: CMSC 325 or CMSC 315 (or CMSC 350)
# CMSC 412: (CMSC 310 | CMSC 311)
# CMSC 415: (CMSC 320 | CMIS 320)
# CMSC 420: CMSC 320 (or CMIS 320), IFSM 410, or IFSM 411
# CMSC 425: (CMSC 215 | CMIS 242)
# CMSC 427: CMSC 315 (or CMSC 350) or SDEV 300
# CMSC 440: CMSC 215 (or CMIS 242) and CMSC 320 (or CMIS 320)
# CMSC 451: CMSC 150 and CMSC 315 (or CMIS 350)
# CMSC 465: MATH 141 and CMSC 315 (or CMSC 350)
# CMSC 486A: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# CMSC 486B: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# CMSC 498: Vary according to topic
# CMST 486A: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# CMST 486B: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# CMST 495: Completion of 24 credits within the major
# CCJS 301: (CCJS 100 | CCJS 101 | CCJS 105)
# CCJS 342: (CCJS 100 | CCJS 101 | CCJS 105)
# CCJS 416: (CCJS 100 | CCJS 105)
# CCJS 420: (CCJS 101 | CCJS 100 | CCJS 105)
# CCJS 486A: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# CCJS 486B: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# CCJS 495: CCJS 230, CCJS 340, CCJS 341, CCJS 345, and CCJS 380
# CCJS 497: CCJS 230, CCJS 340, CCJS 341, CCJS 345, and CCJS 380
# CSIA 300: Any CMIS, CMIT, CMSC, CMST, CSIA, DATA, IFSM, or SDEV course
# CSIA 310: IFSM 201 and WRTG 112 or equivalent
# CSIA 459: (CMIT 320 & CSIA 350)
# CSIA 486A: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# CSIA 486B: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# DATA 230: STAT 200 and MATH 115 (or MATH 107 and MATH 108) or higher
# DATA 440: (DATA 230 & DATA 430)
# DATA 445: (DATA 335 & DATA 430)
# DATA 495: (DATA 440 & DATA 445 & DATA 450)
# ECON 430: (ECON 201 & ECON 203)
# ECON 440: (ECON 201 & ECON 203)
# EDTP 500: Departmental approval; completion of  90 credits of coursework, including at least 24 credits in content area coursework; and a GPA of at least 2.75 in content area coursework
# EMGT 302: WRTG 112 or equivalent
# EMGT 486A: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# EMGT 486B: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# ENGL 102: WRTG 112 or equivalent
# ENGL 240: WRTG 112 or equivalent
# ENGL 281: WRTG 112 or equiva-lent
# ENGL 303: WRTG 112 or equivalent
# ENGL 310: WRTG 112 or equivalent
# ENGL 311: WRTG 112 or equivalent
# ENGL 363: WRTG 112 or equivalent
# ENGL 364: WRTG 112 or equivalent
# ENGL 381: WRTG 112 or equivalent
# ENGL 384: WRTG 112 or equiva-lent
# ENGL 439: WRTG 112 or equivalent
# ENGL 441: WRTG 112 or equivalent
# ENGL 495: ENGL 240, ENGL 303, and at least 9 additional credits of upper-level ENGL courses
# ENGL 386: WRTG 112 or equivalent
# ENGL 406: WRTG 112 or equivalent
# ENGL 418: WRTG 112 or equivalent
# ENGL 430: WRTG 112 or equivalent
# ENGL 433: WRTG 112 or equivalent
# ENHS 495: Completion of 30 credits of ENHS courses, includ-ing ENHS 305, ENHS 330, and ENHS 340
# FINC 330: (ACCT 221 & STAT 200)
# FINC 340: (FINC 330 & FINC 335)
# FINC 450: (FINC 330 & FINC 340)
# FINC 486A: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# FINC 486B: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# FINC 490: ACCT 323, FINC 321, FINC 340, FINC 352, and FINC 355
# FINC 495: (FINC 330 & FINC 340)
# FSCN 302: WRTG 112 or equivalent
# FSCN 413: (FSCN 304 & FSCN 305)
# FSCN 416: (FSCN 304 & FSCN 305)
# FREN 112: FREN 111 or appropriate score on a placement test
# GERM 112: GERM 111 or appropriate score on a placement test
# GERM 211: GERM 112 or appropri-ate score on a placement test
# GERM 212: GERM 211 or appropri-ate score on a placement test
# GERM 311: GERM 212 or appropriate score on a placement test
# GERM 314: GERM 212 or appropriate score on a placement test
# GERO 486A: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# GERO 486B: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# GVPT 486A: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# GVPT 486B: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# GVPT 495: WRTG 112 or equivalent and 9 upper-level credits in GVPT coursework
# GRCO 230: (GRCO 100 & ARTT 120)
# GRCO 450: (GRCO 350 & GRCO 355)
# GRCO 479: (GRCO 354 | ARTT 354)
# GRCO 486A: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# GRCO 486B: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# GRCO 495: (GRCO 450 | GRCO 458 | GRCO 479)
# HMGT 300: (WRTG 112 | WRTG 101)
# HMGT 307: (HMGT 300 & STAT 200)
# HMGT 435: HMGT 300 (or BMGT 361) and HMGT 310
# HMGT 486A: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# HMGT 486B: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# HMGT 322: HMGT 300 (or BMGT 361) and HMGT 310
# HMGT 372: (HMGT 300 | NURS 300)
# HMGT 400: (HMGT 320 & STAT 200)
# HIST 289: A 100-level HIST course
# HIST 326: Any writing course
# HIST 381: A writing course
# HIST 392: A writing course
# HIST 461: A writing course
# HIST 464: Any writing course
# HIST 482: A writing course
# HIST 483: A writing course
# HIST 486A: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# HIST 486B: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# HIST 495: 21 credits in HIST courses, including HIST 289 and HIST 309
# HMLS 302: WRTG 112 or equivalent
# HMLS 310: (HMLS 302 & HMLS 406)
# HMLS 495: At least 15 credits in upper-level FSCN, EMGT, HMLS, or PSAD courses (numbered 300 or 400)
# HUMN 495: HUMN 100, an upper-level ARTH course, an upper-level ENGL course, an upper-level HUMN course, and an upper-level PHIL course
# HRMN 486A: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# HRMN 486B: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# IFSM 380: (IFSM 201 | IFSM 300)
# IFSM 438: (IFSM 300 | CSIA 350)
# IFSM 461: IFSM 311 and either IFSM 330 or CMIS 320
# IFSM 486A: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# IFSM 486B: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# IFSM 495: (IFSM 438 & IFSM 461)
# JAPN 112: JAPN 111 or appropriate score on a placement test
# JAPN 114: JAPN 112 or appropriate score on a placement test
# JAPN 115: JAPN 114 or appropriate score on a placement test
# JAPN 221: JAPN 115 or appropriate score on a placement test
# JAPN 222: JAPN 221 or appropriate score on a placement test
# JOUR 201: WRTG 112 or equivalent
# JOUR 486A: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# JOUR 486B: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# LGST 486A: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# LGST 486B: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# MRKT 394: (MRKT 310 | MRKT 311)
# MRKT 411: (MRKT 310 | MRKT 311)
# MRKT 354: (MRKT 310 | MRKT 311)
# MRKT 356: (MRKT 310 | MRKT 311)
# MRKT 495: (MRKT 354 & MRKT 410 & MRKT 412)
# MRKT 412: (MRKT 310 | MRKT 311)
# MRKT 458: (MRKT 310 | MRKT 311)
# MRKT 486A: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# MRKT 486B: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# MATH 140: (MATH 108 | MATH 115)
# MATH 246: (MATH 141 | MATH 132)
# NSCI 100: MATH 105, STAT 200, or a higher MATH or STAT course
# NSCI 101: MATH 105, STAT 200, or a higher MATH or STAT course
# NSCI 103: MATH 105, STAT 200, or a higher MATH or STAT course
# NSCI 120: MATH 105, STAT 200, or a higher MATH or STAT course
# NURS 462: (NURS 360 | NURS 362)
# PHYS 121: MATH 108, MATH 115, or knowledge of college-level trigonometry
# PSYC 300: (PSYC 100 & STAT 200)
# PSYC 495: PSYC 100, PSYC 300, and completion of all require-ments for the psychology major
# PSAD 302: WRTG 112 or equivalent
# PSAD 486A: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# PSAD 486B: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# PSAD 495: PSAD 306, PSAD 408, PSAD 410, PSAD 414, and PSAD 416
# SOCY 486A: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# SOCY 486B: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# SDEV 325: (CMSC 320 & SDEV 300)
# SDEV 425: (SDEV 325 & SDEV 360)
# SDEV 486A: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# SDEV 486B: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# SPAN 112: SPAN 111 or appropriate score on a placement test
# SPAN 211: SPAN 112 or appropri-ate score on a placement test
# SPAN 212: SPAN 211 or appropri-ate score on a placement test
# SPAN 311: SPAN 212 or appropriate score on a placement test
# SPAN 314: SPAN 212 or appropriate score on a placement test
# SPAN 418: Any 300-level SPAN course or appropriate score on a placement test
# SPAN 419: Any 300-level SPAN course or appropriate score on a placement test
# SPAN 486A: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# SPAN 486B: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# SPCH 324: Any SPCH course or COMM 300
# SPCH 470: Any SPCH course or COMM 300
# SPCH 472: Any SPCH course or COMM 300
# SPCH 482: Any SPCH course or COMM 300
# WRTG 394: WRTG 112 or equivalent
# WRTG 291: WRTG 112 or equivalent
# WRTG 293: WRTG 112 or equivalent
# WRTG 391: WRTG 112 or equivalent
# WRTG 393: WRTG 112 or equivalent
# ACCT 610: 15 credits of undergraduate accounting
# ACCT 611: 15 credits of undergraduate accounting
# ACCT 620: (ACCT 610 & ACCT 618)
# ACCT 645: (ACCT 618 & ACCT 628 & ACCT 630)
# ACCT 660: (ACCT 618 & ACCT 628 & ACCT 630 & INFA 610)
# ACCT 670: Completion of all program courses; may be  taken concurrently with ACCT 635 or INFA 660
# MSAF 670: Completion of all program courses except FIN 645
# BIOT 670I: Completion of 30 credits of program course-work, including all core courses
# BIOT 670M: Completion of 30 credits of program coursework, including all core courses
# BIOT 670R: Completion of 30 credits of program coursework, including all core courses
# BIOT 670S: Completion of 30 credits of program coursework, including all core courses
# DBA 600: DBA 600 and full admission to the DBA program
# CCPA 880: Permission of the department
# CJMS 620: (CJMS 600 & CJMS 610)
# CJMS 630: (CJMS 600 & CJMS 610)
# CJMS 640: (CJMS 600 & CJMS 610)
# CJMS 650: (CJMS 600 & CJMS 610)
# CJMS 660: 30 credits of program coursework, including all core and specialization courses except MGMT 670
# CYB 670: (CST 640 | DFC 640 | CMP 640)
# DBST 670: 30 credits of program coursework, including all core courses
# OMDE 603: (OMDE 601 & OMDE 610)
# OMDE 606: (OMDE 603 & OMDE 608)
# OMDE 670: (DEPM 604 & DETT 621)
# DEPM 604: (DETT 607 & DETC 620)
# DEPM 609: (OMDE 601 & OMDE 603 & OMDE 608)
# DEPM 622: (DEPM 604 & DETT 621)
# DEPM 650: (OMDE 601 & OMDE 603 & OMDE 608)
# DETT 607: (OMDE 606 & DETT 611)
# DETT 611: (OMDE 603 & OMDE 608)
# DETT 621: (DETT 607 & DETC 620)
# DETC 620: (OMDE 606 & DETT 611)
# EDTP 639: (EDTP 600 & EDTP 635)
# EDTP 645: (EDTP 600 & EDTP 635)
# EMAN 670: 30 credits, including all core and specialization courses except MGMT 670
# ENVM 670: Completion of 27 credits of program coursework
# HIMS 661: (HCAD 610 & HIMS 655)
# HCAD 670: Completion of 36 credits of program coursework
# HIMS 670: Completion of 30 credits of program coursework, including HIMS 650, HIMS 655, and HIMS 661
# HSMN 670: Completion of 24 credits of program coursework, including HSMN 610, HSMN 625, HSMN 630, EMAN 620, INFA 660, and BSBD 641
# IMAT 670: 30 credits of program coursework
# INFA 670: INFA 610, INFA 620, INFA 630, INFA 640, INFA 650, and INFA 660 (3 credits may be taken concurrently)
# INMS 620: (INMS 600 & INMS 610)
# INMS 650: (INMS 600 & INMS 610)
# INMS 660: Completion of 30 credits of program coursework, including all core and specialization courses (except MGMT 670)
# ISAS 600: Basic micro-computer skills
# MGMT 650: Knowledge of the fundamentals of statistical meth-ods, techniques, and tools
# MGMT 670: Completion of 24 credits of program coursework, including all core courses
# PMAN 650: (PMAN 634 & PMAN 635)
# SWEN 670: 30 credits of program coursework, including all core courses
# SYSE 630: (SYSE 610 & SYSE 620)
# SYSE 640: (SYSE 610 & SYSE 620)
# SYSE 650: (SYSE 610 & SYSE 620)
# SYSE 660: (SYSE 630 & SYSE 640)
# SYSE 670: (SYSE 640 & SYSE 650)

# %%
classes_with_or = {k: v for k, v in classes.items() if ' or ' in v['prerequisites']}

# %%
classes_with_or = {k: {'prerequisites': v['prerequisites']} for k, v in classes.items() if ' or ' in v['prerequisites']}

# %%
classes_with_or
# Out:
# {'ACCT 320': {'prerequisites': 'ACCT 220 or ACCT 301'},
#  'ACCT 323': {'prerequisites': 'ACCT 220 or FINC 321'},
#  'ACCT 350': {'prerequisites': 'ACCT 220 or ACCT 301'},
#  'ACCT 440': {'prerequisites': 'ACCT 320 or ACCT 438'},
#  'ARAB 112': {'prerequisites': 'ARAB 111 or appropriate score on a placement test'},
#  'ARAB 114': {'prerequisites': 'ARAB 112 or appropriate score on a placement test'},
#  'ARAB 115': {'prerequisites': 'ARAB 114 or appropriate score on a place-ment test'},
#  'ASTD 485': {'prerequisites': 'MATH 105, STAT 200, or a higher MATH or STAT course'},
#  'BIOL 164': {'prerequisites': 'BIOL 101, BIOL 103, or BIOL 160'},
#  'BIOL 230': {'prerequisites': 'BIOL 103 or other introductory biology course with laboratory'},
#  'BIOL 357': {'prerequisites': 'BIOL 325 or another upper-level biology course'},
#  'BIOL 362': {'prerequisites': 'BIOL 101, BIOL 103, or BIOL 160'},
#  'BIOL 422': {'prerequisites': 'BIOL 230, BIOL 301, BIOL 302, or BIOL 398G'},
#  'BMGT 365': {'prerequisites': 'BMGT 110 or BMGT 364'},
#  'CHEM 113': {'prerequisites': 'CHEM 103 or CHEM 105'},
#  'CHIN 112': {'prerequisites': 'CHIN 111 or appropriate score on a placement test'},
#  'CHIN 114': {'prerequisites': 'CHIN 112 or appropriate score on a placement test'},
#  'CHIN 115': {'prerequisites': 'CHIN 114 or appropriate score on a place-ment test'},
#  'COMM 300': {'prerequisites': 'WRTG 112 or equiva-lent'},
#  'COMM 202': {'prerequisites': 'WRTG 112 or equiva-lent'},
#  'COMM 302': {'prerequisites': 'WRTG 112, WRTG 101, or WRTG 101S'},
#  'COMM 390': {'prerequisites': 'WRTG 112, WRTG 101, or WRTG 101S'},
#  'COMM 400': {'prerequisites': 'WRTG 112 or equivalent'},
#  'COMM 492': {'prerequisites': 'WRTG 112 or equivalent'},
#  'CMIT 265': {'prerequisites': 'CMIT 202 or CMSC 115 (or CMIS 141)'},
#  'CMIT 291': {'prerequisites': 'CMIT 202 or CMIT 265'},
#  'CMIT 320': {'prerequisites': 'CMIT 265 or CompTIA Network+ certification'},
#  'CMIT 388': {'prerequisites': 'CMIT 291 or CMIT 391'},
#  'CMIT 455': {'prerequisites': 'CMIT 350 or CMIT 352'},
#  'CMSC 340': {'prerequisites': 'CMSC 115 or CMIS 141'},
#  'CMSC 405': {'prerequisites': 'CMSC 325 or CMSC 315 (or CMSC 350)'},
#  'CMSC 412': {'prerequisites': 'CMSC 310 or CMSC 311'},
#  'CMSC 415': {'prerequisites': 'CMSC 320 or CMIS 320'},
#  'CMSC 420': {'prerequisites': 'CMSC 320 (or CMIS 320), IFSM 410, or IFSM 411'},
#  'CMSC 425': {'prerequisites': 'CMSC 215 or CMIS 242'},
#  'CMSC 427': {'prerequisites': 'CMSC 315 (or CMSC 350) or SDEV 300'},
#  'CCJS 301': {'prerequisites': 'CCJS 100, CCJS 101, or CCJS 105'},
#  'CCJS 342': {'prerequisites': 'CCJS 100, CCJS 101, or CCJS 105'},
#  'CCJS 416': {'prerequisites': 'CCJS 100 or CCJS 105'},
#  'CCJS 420': {'prerequisites': 'CCJS 101, CCJS 100, or CCJS 105'},
#  'CSIA 300': {'prerequisites': 'Any CMIS, CMIT, CMSC, CMST, CSIA, DATA, IFSM, or SDEV course'},
#  'CSIA 310': {'prerequisites': 'IFSM 201 and WRTG 112 or equivalent'},
#  'DATA 230': {'prerequisites': 'STAT 200 and MATH 115 (or MATH 107 and MATH 108) or higher'},
#  'EMGT 302': {'prerequisites': 'WRTG 112 or equivalent'},
#  'ENGL 102': {'prerequisites': 'WRTG 112 or equivalent'},
#  'ENGL 240': {'prerequisites': 'WRTG 112 or equivalent'},
#  'ENGL 281': {'prerequisites': 'WRTG 112 or equiva-lent'},
#  'ENGL 303': {'prerequisites': 'WRTG 112 or equivalent'},
#  'ENGL 310': {'prerequisites': 'WRTG 112 or equivalent'},
#  'ENGL 311': {'prerequisites': 'WRTG 112 or equivalent'},
#  'ENGL 363': {'prerequisites': 'WRTG 112 or equivalent'},
#  'ENGL 364': {'prerequisites': 'WRTG 112 or equivalent'},
#  'ENGL 381': {'prerequisites': 'WRTG 112 or equivalent'},
#  'ENGL 384': {'prerequisites': 'WRTG 112 or equiva-lent'},
#  'ENGL 439': {'prerequisites': 'WRTG 112 or equivalent'},
#  'ENGL 441': {'prerequisites': 'WRTG 112 or equivalent'},
#  'ENGL 386': {'prerequisites': 'WRTG 112 or equivalent'},
#  'ENGL 406': {'prerequisites': 'WRTG 112 or equivalent'},
#  'ENGL 418': {'prerequisites': 'WRTG 112 or equivalent'},
#  'ENGL 430': {'prerequisites': 'WRTG 112 or equivalent'},
#  'ENGL 433': {'prerequisites': 'WRTG 112 or equivalent'},
#  'FSCN 302': {'prerequisites': 'WRTG 112 or equivalent'},
#  'FREN 112': {'prerequisites': 'FREN 111 or appropriate score on a placement test'},
#  'GERM 112': {'prerequisites': 'GERM 111 or appropriate score on a placement test'},
#  'GERM 211': {'prerequisites': 'GERM 112 or appropri-ate score on a placement test'},
#  'GERM 212': {'prerequisites': 'GERM 211 or appropri-ate score on a placement test'},
#  'GERM 311': {'prerequisites': 'GERM 212 or appropriate score on a placement test'},
#  'GERM 314': {'prerequisites': 'GERM 212 or appropriate score on a placement test'},
#  'GVPT 495': {'prerequisites': 'WRTG 112 or equivalent and 9 upper-level credits in GVPT coursework'},
#  'GRCO 479': {'prerequisites': 'GRCO 354 or ARTT 354'},
#  'GRCO 495': {'prerequisites': 'GRCO 450, GRCO 458, or GRCO 479'},
#  'HMGT 300': {'prerequisites': 'WRTG 112 or WRTG 101'},
#  'HMGT 372': {'prerequisites': 'HMGT 300 or NURS 300'},
#  'HMLS 302': {'prerequisites': 'WRTG 112 or equivalent'},
#  'HMLS 495': {'prerequisites': 'At least 15 credits in upper-level FSCN, EMGT, HMLS, or PSAD courses (numbered 300 or 400)'},
#  'IFSM 380': {'prerequisites': 'IFSM 201 or IFSM 300'},
#  'IFSM 438': {'prerequisites': 'IFSM 300 or CSIA 350'},
#  'IFSM 461': {'prerequisites': 'IFSM 311 and either IFSM 330 or CMIS 320'},
#  'JAPN 112': {'prerequisites': 'JAPN 111 or appropriate score on a placement test'},
#  'JAPN 114': {'prerequisites': 'JAPN 112 or appropriate score on a placement test'},
#  'JAPN 115': {'prerequisites': 'JAPN 114 or appropriate score on a placement test'},
#  'JAPN 221': {'prerequisites': 'JAPN 115 or appropriate score on a placement test'},
#  'JAPN 222': {'prerequisites': 'JAPN 221 or appropriate score on a placement test'},
#  'JOUR 201': {'prerequisites': 'WRTG 112 or equivalent'},
#  'MRKT 394': {'prerequisites': 'MRKT 310 or MRKT 311'},
#  'MRKT 411': {'prerequisites': 'MRKT 310 or MRKT 311'},
#  'MRKT 354': {'prerequisites': 'MRKT 310 or MRKT 311'},
#  'MRKT 356': {'prerequisites': 'MRKT 310 or MRKT 311'},
#  'MRKT 412': {'prerequisites': 'MRKT 310 or MRKT 311'},
#  'MRKT 458': {'prerequisites': 'MRKT 310 or MRKT 311'},
#  'MATH 140': {'prerequisites': 'MATH 108 or MATH 115'},
#  'MATH 246': {'prerequisites': 'MATH 141 or MATH 132'},
#  'NSCI 100': {'prerequisites': 'MATH 105, STAT 200, or a higher MATH or STAT course'},
#  'NSCI 101': {'prerequisites': 'MATH 105, STAT 200, or a higher MATH or STAT course'},
#  'NSCI 103': {'prerequisites': 'MATH 105, STAT 200, or a higher MATH or STAT course'},
#  'NSCI 120': {'prerequisites': 'MATH 105, STAT 200, or a higher MATH or STAT course'},
#  'NURS 462': {'prerequisites': 'NURS 360 or NURS 362'},
#  'PHYS 121': {'prerequisites': 'MATH 108, MATH 115, or knowledge of college-level trigonometry'},
#  'PSAD 302': {'prerequisites': 'WRTG 112 or equivalent'},
#  'SPAN 112': {'prerequisites': 'SPAN 111 or appropriate score on a placement test'},
#  'SPAN 211': {'prerequisites': 'SPAN 112 or appropri-ate score on a placement test'},
#  'SPAN 212': {'prerequisites': 'SPAN 211 or appropri-ate score on a placement test'},
#  'SPAN 311': {'prerequisites': 'SPAN 212 or appropriate score on a placement test'},
#  'SPAN 314': {'prerequisites': 'SPAN 212 or appropriate score on a placement test'},
#  'SPAN 418': {'prerequisites': 'Any 300-level SPAN course or appropriate score on a placement test'},
#  'SPAN 419': {'prerequisites': 'Any 300-level SPAN course or appropriate score on a placement test'},
#  'SPCH 324': {'prerequisites': 'Any SPCH course or COMM 300'},
#  'SPCH 470': {'prerequisites': 'Any SPCH course or COMM 300'},
#  'SPCH 472': {'prerequisites': 'Any SPCH course or COMM 300'},
#  'SPCH 482': {'prerequisites': 'Any SPCH course or COMM 300'},
#  'WRTG 394': {'prerequisites': 'WRTG 112 or equivalent'},
#  'WRTG 291': {'prerequisites': 'WRTG 112 or equivalent'},
#  'WRTG 293': {'prerequisites': 'WRTG 112 or equivalent'},
#  'WRTG 391': {'prerequisites': 'WRTG 112 or equivalent'},
#  'WRTG 393': {'prerequisites': 'WRTG 112 or equivalent'},
#  'ACCT 670': {'prerequisites': 'Completion of all program courses; may be  taken concurrently with ACCT 635 or INFA 660'},
#  'CYB 670': {'prerequisites': 'CST 640, DFC 640, or CMP 640'}}

# %%
phrase = 'STAT 221 or MATH 441'
match = course_or_list2.search(phrase)
match.groups()
# Out:
# ('STAT 221', 'MATH 441')

# %%
if match:
    print ('(' + match.group(1) + ' | ' + match.group(2) + ')')
# Out:
# (STAT 221 | MATH 441)

# %%
phrase = 'BIOL 230, BIOL 301, BIOL 302, or BIOL 398G'
match = course_or_list4.search(phrase)
groups = match.groups()
groups
# Out:
# ('BIOL 230', 'BIOL 301', 'BIOL 302', 'BIOL 398G')

# %%
# Convert to a single string with '|'
result_string = f'({ " | ".join(groups) })'
result_string
# Out:
# '(BIOL 230 | BIOL 301 | BIOL 302 | BIOL 398G)'

# %%
course_pattern = re.compile(r'([A-Z]{3}[A-Z]? \d{3}[A-Z]?)')
course_pattern_or = re.compile(r'([A-Z]{3}[A-Z]? \d{3}[A-Z]?) or ([A-Z]{3}[A-Z]? \d{3}[A-Z]?)')

def replace_classes(match):
    classes = re.split(r' or |, ', match.group(1))
    return '(' + ' | '.join(classes) + ')'

# Using regex to filter classes with prerequisites matching the pattern '[A-Z]{4} \d{3}'
pattern = re.compile('[A-Z]{4} \d{3}')
classes_with_regex = {k: v for k, v in classes.items() if course_pattern.search(v['prerequisites'])}

# %%
course_pattern_and = re.compile(r'([A-Z]{3}[A-Z]? \d{3}[A-Z]?) or ([A-Z]{3}[A-Z]? \d{3}[A-Z]?)')

# %%
phrase = 'STAT 221, STAT 536, or MATH 441'

# %%
course_pattern_or = re.compile(r'([A-Z]{3}[A-Z]? \d{3}[A-Z]?) or ([A-Z]{3}[A-Z]? \d{3}[A-Z]?)')
phrase = 'STAT 221 or MATH 441'
match = course_pattern_or.search(phrase)
if match:
    print ('(' + match.group(1) + ' | ' + match.group(2) + ')')
# Out:
# (STAT 221 | MATH 441)

# %%
course_pattern_and = re.compile(r'([A-Z]{3}[A-Z]? \d{3}[A-Z]?) and ([A-Z]{3}[A-Z]? \d{3}[A-Z]?)')
phrase = 'STAT 221 and MATH 441'
match = course_pattern_and.search(phrase)
if match:
    print ('(' + match.group(1) + ' & ' + match.group(2) + ')')
# Out:
# (STAT 221 & MATH 441)

# %%
modified_phrase = re.sub(course_pattern, replace_classes, phrase)

print(modified_phrase)

# %%
phrase = 'MATH 140, MATH 141, or PHYS 101'

modified_phrase = re.sub(course_pattern, replace_classes, phrase)

print(modified_phrase)
# Out:
# (MATH 140), (MATH 141), or (PHYS 101)

# %%
len(courses)
# Out:
# 970

# %%
classes_with_and = {k: {'name': v['name'], 'prerequisites': v['prerequisites']} for k, v in classes.items() if ' and ' in v['prerequisites']}

# %%
classes_with_and
# Out:
# {'ACCT 417': {'name': 'ACCT 417', 'prerequisites': 'ACCT 311 and ACCT 323'},
#  'ACCT 486A': {'name': 'ACCT 486A',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'ACCT 486B': {'name': 'ACCT 486B',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'BEHS 300': {'name': 'BEHS 300', 'prerequisites': 'BEHS 210 and STAT 200'},
#  'BEHS 486A': {'name': 'BEHS 486A',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'BEHS 486B': {'name': 'BEHS 486B',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'BEHS 495': {'name': 'BEHS 495',
#   'prerequisites': 'BEHS 300 and completion of all requirements for the social science major'},
#  'BIOL 486A': {'name': 'BIOL 486A',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'BIOL 486B': {'name': 'BIOL 486B',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'BMGT 485': {'name': 'BMGT 485',
#   'prerequisites': 'BMGT 317, BMGT 364, BMGT 464 (or BMGT 465), and BMGT 484'},
#  'BMGT 486A': {'name': 'BMGT 486A',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'BMGT 486B': {'name': 'BMGT 486B',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'BMGT 495': {'name': 'BMGT 495',
#   'prerequisites': 'BMGT 364, BMGT 365, FINC 330 (or BMGT 340), and MRKT 310'},
#  'COMM 480': {'name': 'COMM 480', 'prerequisites': 'COMM 300 and COMM 302'},
#  'COMM 486A': {'name': 'COMM 486A',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'COMM 486B': {'name': 'COMM 486B',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'COMM 495': {'name': 'COMM 495',
#   'prerequisites': 'COMM 300, COMM 302, and at least 9 additional credits of upper-level COMM, SPCH, and/or JOUR courses'},
#  'CMIT 380': {'name': 'CMIT 380', 'prerequisites': 'CMIT 202 and CMIT 320'},
#  'CMIT 420': {'name': 'CMIT 420', 'prerequisites': 'CMIT 320 and CMIT 382'},
#  'CMIT 422': {'name': 'CMIT 422', 'prerequisites': 'CMIT 320 and CMIT 382'},
#  'CMIT 424': {'name': 'CMIT 424',
#   'prerequisites': 'CMIT 202 (or CompTIA A+ certification), CMIT 320 (or CompTIA Security+ certification), and CCJS 321'},
#  'CMIT 460': {'name': 'CMIT 460', 'prerequisites': 'CMIT 320 and CMIT 424'},
#  'CMIT 486A': {'name': 'CMIT 486A',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'CMIT 486B': {'name': 'CMIT 486B',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'CMSC 440': {'name': 'CMSC 440',
#   'prerequisites': 'CMSC 215 (or CMIS 242) and CMSC 320 (or CMIS 320)'},
#  'CMSC 451': {'name': 'CMSC 451',
#   'prerequisites': 'CMSC 150 and CMSC 315 (or CMIS 350)'},
#  'CMSC 465': {'name': 'CMSC 465',
#   'prerequisites': 'MATH 141 and CMSC 315 (or CMSC 350)'},
#  'CMSC 486A': {'name': 'CMSC 486A',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'CMSC 486B': {'name': 'CMSC 486B',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'CMST 486A': {'name': 'CMST 486A',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'CMST 486B': {'name': 'CMST 486B',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'CCJS 486A': {'name': 'CCJS 486A',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'CCJS 486B': {'name': 'CCJS 486B',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'CCJS 495': {'name': 'CCJS 495',
#   'prerequisites': 'CCJS 230, CCJS 340, CCJS 341, CCJS 345, and CCJS 380'},
#  'CCJS 497': {'name': 'CCJS 497',
#   'prerequisites': 'CCJS 230, CCJS 340, CCJS 341, CCJS 345, and CCJS 380'},
#  'CSIA 310': {'name': 'CSIA 310',
#   'prerequisites': 'IFSM 201 and WRTG 112 or equivalent'},
#  'CSIA 459': {'name': 'CSIA 459', 'prerequisites': 'CMIT 320 and CSIA 350'},
#  'CSIA 486A': {'name': 'CSIA 486A',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'CSIA 486B': {'name': 'CSIA 486B',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'DATA 230': {'name': 'DATA 230',
#   'prerequisites': 'STAT 200 and MATH 115 (or MATH 107 and MATH 108) or higher'},
#  'DATA 440': {'name': 'DATA 440', 'prerequisites': 'DATA 230 and DATA 430'},
#  'DATA 445': {'name': 'DATA 445', 'prerequisites': 'DATA 335 and DATA 430'},
#  'DATA 495': {'name': 'DATA 495',
#   'prerequisites': 'DATA 440, DATA 445, and DATA 450'},
#  'ECON 430': {'name': 'ECON 430', 'prerequisites': 'ECON 201 and ECON 203'},
#  'ECON 440': {'name': 'ECON 440', 'prerequisites': 'ECON 201 and ECON 203'},
#  'EDTP 500': {'name': 'EDTP 500',
#   'prerequisites': 'Departmental approval; completion of  90 credits of coursework, including at least 24 credits in content area coursework; and a GPA of at least 2.75 in content area coursework'},
#  'EMGT 486A': {'name': 'EMGT 486A',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'EMGT 486B': {'name': 'EMGT 486B',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'ENGL 495': {'name': 'ENGL 495',
#   'prerequisites': 'ENGL 240, ENGL 303, and at least 9 additional credits of upper-level ENGL courses'},
#  'ENHS 495': {'name': 'ENHS 495',
#   'prerequisites': 'Completion of 30 credits of ENHS courses, includ-ing ENHS 305, ENHS 330, and ENHS 340'},
#  'FINC 330': {'name': 'FINC 330', 'prerequisites': 'ACCT 221 and STAT 200'},
#  'FINC 340': {'name': 'FINC 340', 'prerequisites': 'FINC 330 and FINC 335'},
#  'FINC 450': {'name': 'FINC 450', 'prerequisites': 'FINC 330 and FINC 340'},
#  'FINC 486A': {'name': 'FINC 486A',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'FINC 486B': {'name': 'FINC 486B',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'FINC 490': {'name': 'FINC 490',
#   'prerequisites': 'ACCT 323, FINC 321, FINC 340, FINC 352, and FINC 355'},
#  'FINC 495': {'name': 'FINC 495', 'prerequisites': 'FINC 330 and FINC 340'},
#  'FSCN 413': {'name': 'FSCN 413', 'prerequisites': 'FSCN 304 and FSCN 305'},
#  'FSCN 416': {'name': 'FSCN 416', 'prerequisites': 'FSCN 304 and FSCN 305'},
#  'GERO 486A': {'name': 'GERO 486A',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'GERO 486B': {'name': 'GERO 486B',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'GVPT 486A': {'name': 'GVPT 486A',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'GVPT 486B': {'name': 'GVPT 486B',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'GVPT 495': {'name': 'GVPT 495',
#   'prerequisites': 'WRTG 112 or equivalent and 9 upper-level credits in GVPT coursework'},
#  'GRCO 230': {'name': 'GRCO 230', 'prerequisites': 'GRCO 100 and ARTT 120'},
#  'GRCO 450': {'name': 'GRCO 450', 'prerequisites': 'GRCO 350 and GRCO 355'},
#  'GRCO 486A': {'name': 'GRCO 486A',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'GRCO 486B': {'name': 'GRCO 486B',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'HMGT 307': {'name': 'HMGT 307', 'prerequisites': 'HMGT 300 and STAT 200'},
#  'HMGT 435': {'name': 'HMGT 435',
#   'prerequisites': 'HMGT 300 (or BMGT 361) and HMGT 310'},
#  'HMGT 486A': {'name': 'HMGT 486A',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'HMGT 486B': {'name': 'HMGT 486B',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'HMGT 322': {'name': 'HMGT 322',
#   'prerequisites': 'HMGT 300 (or BMGT 361) and HMGT 310'},
#  'HMGT 400': {'name': 'HMGT 400', 'prerequisites': 'HMGT 320 and STAT 200'},
#  'HIST 486A': {'name': 'HIST 486A',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'HIST 486B': {'name': 'HIST 486B',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'HIST 495': {'name': 'HIST 495',
#   'prerequisites': '21 credits in HIST courses, including HIST 289 and HIST 309'},
#  'HMLS 310': {'name': 'HMLS 310', 'prerequisites': 'HMLS 302 and HMLS 406'},
#  'HUMN 495': {'name': 'HUMN 495',
#   'prerequisites': 'HUMN 100, an upper-level ARTH course, an upper-level ENGL course, an upper-level HUMN course, and an upper-level PHIL course'},
#  'HRMN 486A': {'name': 'HRMN 486A',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'HRMN 486B': {'name': 'HRMN 486B',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'IFSM 461': {'name': 'IFSM 461',
#   'prerequisites': 'IFSM 311 and either IFSM 330 or CMIS 320'},
#  'IFSM 486A': {'name': 'IFSM 486A',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'IFSM 486B': {'name': 'IFSM 486B',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'IFSM 495': {'name': 'IFSM 495', 'prerequisites': 'IFSM 438 and IFSM 461'},
#  'JOUR 486A': {'name': 'JOUR 486A',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'JOUR 486B': {'name': 'JOUR 486B',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'LGST 486A': {'name': 'LGST 486A',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'LGST 486B': {'name': 'LGST 486B',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'MRKT 495': {'name': 'MRKT 495',
#   'prerequisites': 'MRKT 354, MRKT 410, and MRKT 412'},
#  'MRKT 486A': {'name': 'MRKT 486A',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'MRKT 486B': {'name': 'MRKT 486B',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'PSYC 300': {'name': 'PSYC 300', 'prerequisites': 'PSYC 100 and STAT 200'},
#  'PSYC 495': {'name': 'PSYC 495',
#   'prerequisites': 'PSYC 100, PSYC 300, and completion of all require-ments for the psychology major'},
#  'PSAD 486A': {'name': 'PSAD 486A',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'PSAD 486B': {'name': 'PSAD 486B',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'PSAD 495': {'name': 'PSAD 495',
#   'prerequisites': 'PSAD 306, PSAD 408, PSAD 410, PSAD 414, and PSAD 416'},
#  'SOCY 486A': {'name': 'SOCY 486A',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'SOCY 486B': {'name': 'SOCY 486B',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'SDEV 325': {'name': 'SDEV 325', 'prerequisites': 'CMSC 320 and SDEV 300'},
#  'SDEV 425': {'name': 'SDEV 425', 'prerequisites': 'SDEV 325 and SDEV 360'},
#  'SDEV 486A': {'name': 'SDEV 486A',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'SDEV 486B': {'name': 'SDEV 486B',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'SPAN 486A': {'name': 'SPAN 486A',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'SPAN 486B': {'name': 'SPAN 486B',
#   'prerequisites': '9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)'},
#  'ACCT 620': {'name': 'ACCT 620', 'prerequisites': 'ACCT 610 and ACCT 618'},
#  'ACCT 645': {'name': 'ACCT 645',
#   'prerequisites': 'ACCT 618, ACCT 628, and ACCT 630'},
#  'ACCT 660': {'name': 'ACCT 660',
#   'prerequisites': 'ACCT 618, ACCT 628, ACCT 630, and INFA 610'},
#  'DBA 600': {'name': 'DBA 600',
#   'prerequisites': 'DBA 600 and full admission to the DBA program'},
#  'CJMS 620': {'name': 'CJMS 620', 'prerequisites': 'CJMS 600 and CJMS 610'},
#  'CJMS 630': {'name': 'CJMS 630', 'prerequisites': 'CJMS 600 and CJMS 610'},
#  'CJMS 640': {'name': 'CJMS 640', 'prerequisites': 'CJMS 600 and CJMS 610'},
#  'CJMS 650': {'name': 'CJMS 650', 'prerequisites': 'CJMS 600 and CJMS 610'},
#  'CJMS 660': {'name': 'CJMS 660',
#   'prerequisites': '30 credits of program coursework, including all core and specialization courses except MGMT 670'},
#  'OMDE 603': {'name': 'OMDE 603', 'prerequisites': 'OMDE 601 and OMDE 610'},
#  'OMDE 606': {'name': 'OMDE 606', 'prerequisites': 'OMDE 603 and OMDE 608'},
#  'OMDE 670': {'name': 'OMDE 670', 'prerequisites': 'DEPM 604 and DETT 621'},
#  'DEPM 604': {'name': 'DEPM 604', 'prerequisites': 'DETT 607 and DETC 620'},
#  'DEPM 609': {'name': 'DEPM 609',
#   'prerequisites': 'OMDE 601, OMDE 603, and OMDE 608'},
#  'DEPM 622': {'name': 'DEPM 622', 'prerequisites': 'DEPM 604 and DETT 621'},
#  'DEPM 650': {'name': 'DEPM 650',
#   'prerequisites': 'OMDE 601, OMDE 603, and OMDE 608'},
#  'DETT 607': {'name': 'DETT 607', 'prerequisites': 'OMDE 606 and DETT 611'},
#  'DETT 611': {'name': 'DETT 611', 'prerequisites': 'OMDE 603 and OMDE 608'},
#  'DETT 621': {'name': 'DETT 621', 'prerequisites': 'DETT 607 and DETC 620'},
#  'DETC 620': {'name': 'DETC 620', 'prerequisites': 'OMDE 606 and DETT 611'},
#  'EDTP 639': {'name': 'EDTP 639', 'prerequisites': 'EDTP 600 and EDTP 635'},
#  'EDTP 645': {'name': 'EDTP 645', 'prerequisites': 'EDTP 600 and EDTP 635'},
#  'EMAN 670': {'name': 'EMAN 670',
#   'prerequisites': '30 credits, including all core and specialization courses except MGMT 670'},
#  'HIMS 661': {'name': 'HIMS 661', 'prerequisites': 'HCAD 610 and HIMS 655'},
#  'HIMS 670': {'name': 'HIMS 670',
#   'prerequisites': 'Completion of 30 credits of program coursework, including HIMS 650, HIMS 655, and HIMS 661'},
#  'HSMN 670': {'name': 'HSMN 670',
#   'prerequisites': 'Completion of 24 credits of program coursework, including HSMN 610, HSMN 625, HSMN 630, EMAN 620, INFA 660, and BSBD 641'},
#  'INFA 670': {'name': 'INFA 670',
#   'prerequisites': 'INFA 610, INFA 620, INFA 630, INFA 640, INFA 650, and INFA 660 (3 credits may be taken concurrently)'},
#  'INMS 620': {'name': 'INMS 620', 'prerequisites': 'INMS 600 and INMS 610'},
#  'INMS 650': {'name': 'INMS 650', 'prerequisites': 'INMS 600 and INMS 610'},
#  'INMS 660': {'name': 'INMS 660',
#   'prerequisites': 'Completion of 30 credits of program coursework, including all core and specialization courses (except MGMT 670)'},
#  'MGMT 650': {'name': 'MGMT 650',
#   'prerequisites': 'Knowledge of the fundamentals of statistical meth-ods, techniques, and tools'},
#  'PMAN 650': {'name': 'PMAN 650', 'prerequisites': 'PMAN 634 and PMAN 635'},
#  'SYSE 630': {'name': 'SYSE 630', 'prerequisites': 'SYSE 610 and SYSE 620'},
#  'SYSE 640': {'name': 'SYSE 640', 'prerequisites': 'SYSE 610 and SYSE 620'},
#  'SYSE 650': {'name': 'SYSE 650', 'prerequisites': 'SYSE 610 and SYSE 620'},
#  'SYSE 660': {'name': 'SYSE 660', 'prerequisites': 'SYSE 630 and SYSE 640'},
#  'SYSE 670': {'name': 'SYSE 670', 'prerequisites': 'SYSE 640 and SYSE 650'}}

# %% [markdown]
# ### Add Data to the MySQL DB

# %%
from sqlalchemy import create_engine, Column, Integer, String, Sequence, Text, create_engine
from sqlalchemy.orm import declarative_base, Session

# Replace 'root' and 'root' with your MySQL username and password
db_username = 'root'
db_password = 'root'
db_name = 'umgc'
socket_path = '/tmp/mysql.sock'  # Specify the path to your MySQL socket

# Create the MySQL engine with the socket information
engine = create_engine(f'mysql+mysqlconnector://{db_username}:{db_password}@localhost/{db_name}?unix_socket={socket_path}')

Base = declarative_base()

# %%
# Define the Course class as a model
class Course(Base):
    __tablename__ = 'courses'

    id = Column(Integer, Sequence('course_id_seq'), primary_key=True)
    name = Column(String(20), unique=True)
    title = Column(String(120))
    credit = Column(String(5))
    description = Column(Text)
    prerequisites = Column(Text)
    recommended = Column(Text)
    warnings = Column(Text)
    substitutions = Column(Text)

# Create the table in the database
Base.metadata.create_all(engine)

# %%
# Insert data into the 'courses' table
with Session(engine) as session:
    for course_info in courses:
        course = Course(**course_info)
        session.add(course)
    session.commit()

# %%
# Query courses starting with 'STAT'
with Session(engine) as session:
    stat_courses = session.query(Course).filter(Course.name.like('STAT%')).all()

    for course in stat_courses:
        print(f"Course Name: {course.name}, Credit: {course.credit}, Prerequisites: {course.prerequisites}")
# Out:
# Course Name: STAT 200, Credit: 3, Prerequisites:
# Course Name: STAT 400, Credit: 3, Prerequisites: MATH 141

# %%
# Query courses starting with 'STAT'
with Session(engine) as session:
    stat_courses = session.query(Course).filter(Course.name.like('STAT%')).all()

    for course in stat_courses:
        print(f"Course Name: {course.name}, Credit: {course.credit}, Prerequisites: {course.prerequisites}")
# Out:
# Course Name: STAT 200, Credit: 3, Prerequisites:
# Course Name: STAT 400, Credit: 3, Prerequisites: MATH 141

# %%
classes['MATH 141']['prerequisites']
# Out:
# 'MATH 140'

# %%
classes['MATH 108']['prerequisites']
# Out:
# 'MATH 107'

# %%
classes['MATH 107']['prerequisites']
# Out:
# ''

# %%
classes['MATH 115']['prerequisites']
# Out:
# ''

# %%
# Prerequisites for STAT 400: ['MATH 141', 'MATH 140', [['MATH 108', 'MATH 107'], ['MATH 115']]]

# Prerequisites for STAT 400: ['MATH 141', 'MATH 140', [['MATH 108', 'MATH 107'], 
#                                                       ['MATH 115']]]

# %%
def small_pre(course_name, classes):
    if 'prerequisites' in classes[course_name]:
        prerequisite_str = classes[course_name]['prerequisites']
        if prerequisite_str == '':
            return []
        else:
            # will probably need to use regex to extract the classes
            prerequisite_list = [pre.strip() for pre in pre_str.split('or')]
            return prerequisite_list
    else:
        return []
    # returning a list for the time being, will process to return a string

# %%
all_prerequisites = []
course_name = 'STAT 400'

# %%
current_branch = []
course_list = small_pre(course_name, classes)
course_list
# Out:
# ['MATH 141']

# %%
course_name = course_list[0]
current_branch.append(course_name)
current_branch
# Out:
# ['MATH 141']

# %%
course_list = small_pre(course_name, classes)
course_list
# Out:
# ['MATH 140']

# %%
course_name = course_list[0]
current_branch.append(course_name)
current_branch
# Out:
# ['MATH 141', 'MATH 140']

# %%
course_list = small_pre(course_name, classes)
course_list
# Out:
# ['MATH 108', 'MATH 115']

# %%
# make a current branch for the first course, then another for the second course

# %%
multi_branch = []
current_branch_1 = []

course_name = course_list[0]
course_name
# Out:
# 'MATH 108'

# %%
current_branch_1.append(course_name)
current_branch_1
# Out:
# ['MATH 108']

# %%
course_list = small_pre(course_name, classes)
course_list
# Out:
# ['MATH 107']

# %%
course_name = course_list[0]
course_name
# Out:
# 'MATH 107'

# %%
current_branch_1.append(course_name)
current_branch_1
# Out:
# ['MATH 108', 'MATH 107']

# %%
course_list = small_pre(course_name, classes)
course_list
# Out:
# []

# %%
# Since course_list is empty, append current_branch_1 to multi_branch

# %%
multi_branch.append(current_branch_1)
multi_branch
# Out:
# [['MATH 108', 'MATH 107']]

# %%
# now repeat the process for 'MATH 115'

# %%
current_branch_2 = []
## better: 
## for course_name in course_list:
# course_name = course_list[1]
course_name = 'MATH 115'
course_name
# Out:
# 'MATH 115'

# %%
current_branch_2.append(course_name)
current_branch_2
# Out:
# ['MATH 115']

# %%
course_list = small_pre(course_name, classes)
course_list
# Out:
# ['STAT 101', 'MATH 100']

# %%
# Note: These are "and" instead of "or"

# %%
classes[course_name]['prerequisites']
# Out:
# ''

# %%
'pre' in classes[course_name]
# Out:
# False

# %%
'prerequisites' in classes[course_name]
# Out:
# True

# %%
classes[course_name]['prerequisites'] == ''
# Out:
# False

# %%
prerequisites_str = classes[course_name]['prerequisites']
prerequisites_str
# Out:
# 'MATH 141'

# %%
prerequisites_list = [prerequisite.strip() for prerequisite in prerequisites_str.split('or')]
prerequisites_list
# Out:
# ['MATH 141']

# %%
prelist = ['STAT 400', 'MATH 141', 'MATH 140', ['|', ['MATH 108', 'MATH 107'], ['MATH 115', ['&',['STAT 101'],['MATH 100']]]]]

# %%
prelist
# Out:
# ['STAT 400',
#  'MATH 141',
#  'MATH 140',
#  ['|',
#   ['MATH 108', 'MATH 107'],
#   ['MATH 115', ['&', ['STAT 101'], ['MATH 100']]]]]

# %%
prelist[0]
# Out:
# 'STAT 400'

# %%
prelist[1]
# Out:
# 'MATH 141'

# %%
prelist[2]
# Out:
# 'MATH 140'

# %%
prelist[3]
# Out:
# ['|',
#  ['MATH 108', 'MATH 107'],
#  ['MATH 115', ['&', ['STAT 101'], ['MATH 100']]]]

# %%
#check if it is a list
isinstance(prelist[3], list)
# Out:
# True

# %%
len(prelist[3])
# Out:
# 3

# %%
prelist[3][0]
# Out:
# '|'

# %%
prelist[3][1]
# Out:
# ['MATH 108', 'MATH 107']

# %%
#check if it is a list
isinstance(prelist[3][1], list)
# Out:
# True

# %%
prelist[3][1][0]
# Out:
# 'MATH 108'

# %%
#check if it is a list
isinstance(prelist[3][1][0], list)
# Out:
# False

# %%
prelist[3][2]
# Out:
# ['MATH 115', ['&', ['STAT 101'], ['MATH 100']]]

# %%
#check if it is a list
isinstance(prelist[3][2], list)
# Out:
# True

# %%
prelist[3][2][0]
# Out:
# 'MATH 115'

# %%
prelist[3][2][1]
# Out:
# ['&', ['STAT 101'], ['MATH 100']]

# %%
#check if it is a list
isinstance(prelist[3][2][1], list)
# Out:
# True

# %%
prelist[3][2][1][0]
# Out:
# '&'

# %%
#check if it is a list
not isinstance(prelist[3][2][1][0], list) and prelist[3][2][1][0] == '|'
# Out:
# False

# %%
#check if it is a list
not isinstance(prelist[3][2][1][0], list) and prelist[3][2][1][0] == '&'
# Out:
# True

# %% [markdown]
# # Updated Code

# %%
def find_prerequisites(course_code, classes):
    def recursive_helper(course_code, classes):
        # Check if the course has prerequisites
        if 'prerequisites' in classes[course_code]:
            # Get the raw string of prerequisites for the current course
            prerequisites_str = classes[course_code]['prerequisites']

            # Check if prerequisites are not empty
            if prerequisites_str.strip() != '':
                # Split the raw string into individual prerequisites
                prerequisites_list = [prerequisite.strip() for prerequisite in prerequisites_str.split('or')]

                # Initialize the list to store the current branch of prerequisites
                current_branch = []

                # Process each prerequisite separately
                for prerequisite in prerequisites_list:
                    # Recursively find prerequisites for each prerequisite and add to the current branch
                    current_branch.extend(recursive_helper(prerequisite, classes))

                return current_branch

        # If the course has no prerequisites or empty prerequisites, return an empty list
        return []

    # Call the recursive helper function to get the overall list of courses
    return recursive_helper(course_code, classes)

# %%
# Example usage:
classes = {
    'STAT 400': {'prerequisites': 'MATH 141'},
    'MATH 141': {'prerequisites': 'MATH 140'},
    'MATH 140': {'prerequisites': 'MATH 108 or MATH 115'},
    'MATH 108': {'prerequisites': 'MATH 107'},
    'MATH 107': {'prerequisites': ''},
    'MATH 115': {'prerequisites': 'STAT 101 or MATH 100'},
    'STAT 101': {'prerequisites': ''},
    'MATH 100': {'prerequisites': ''}
}

# %%
course_code = 'STAT 400'
prerequisites = find_prerequisites(course_code, classes)

# %%
print(f"Prerequisites for {course_code}: {prerequisites}")
# Out:
# Prerequisites for STAT 400: []

# %%
# Example usage:
classes = {
    'STAT 400': {'prerequisites': 'MATH 141'},
    'MATH 141': {'prerequisites': 'MATH 140'},
    'MATH 140': {'prerequisites': 'MATH 108 or MATH 115'},
    'MATH 108': {'prerequisites': 'MATH 107'},
    'MATH 107': {'prerequisites': ''},
    'MATH 115': {'prerequisites': 'STAT 101 or MATH 100'},
    'STAT 101': {'prerequisites': ''},
    'MATH 100': {'prerequisites': ''}
}

# %%
course_code = 'STAT 400'
prerequisites = find_prerequisites(course_code, classes)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[145], line 2
#       1 course_code = 'STAT 400'
# ----> 2 prerequisites = find_prerequisites(course_code, classes)
#
# Cell In[143], line 25, in find_prerequisites(course_code, classes)
#      22     return [course_code]
#      24 # Call the recursive helper function to get the overall list of courses
# ---> 25 return recursive_helper(course_code, classes)
#
# Cell In[143], line 17, in find_prerequisites.<locals>.recursive_helper(course_code, classes)
#      14     # Process each prerequisite separately
#      15     for prerequisite in prerequisites_list:
#      16         # Recursively find prerequisites for each prerequisite and add to the current branch
# ---> 17         current_branch.extend(recursive_helper(prerequisite, classes))
#      19     return current_branch
#      21 # If the course has no prerequisites, return it as a single-item list
#
# Cell In[143], line 17, in find_prerequisites.<locals>.recursive_helper(course_code, classes)
#      14     # Process each prerequisite separately
#      15     for prerequisite in prerequisites_list:
#      16         # Recursively find prerequisites for each prerequisite and add to the current branch
# ---> 17         current_branch.extend(recursive_helper(prerequisite, classes))
#      19     return current_branch
#      21 # If the course has no prerequisites, return it as a single-item list
#
#     [... skipping similar frames: find_prerequisites.<locals>.recursive_helper at line 17 (2 times)]
#
# Cell In[143], line 17, in find_prerequisites.<locals>.recursive_helper(course_code, classes)
#      14     # Process each prerequisite separately
#      15     for prerequisite in prerequisites_list:
#      16         # Recursively find prerequisites for each prerequisite and add to the current branch
# ---> 17         current_branch.extend(recursive_helper(prerequisite, classes))
#      19     return current_branch
#      21 # If the course has no prerequisites, return it as a single-item list
#
# Cell In[143], line 4, in find_prerequisites.<locals>.recursive_helper(course_code, classes)
#       2 def recursive_helper(course_code, classes):
#       3     # Check if the course has prerequisites
# ----> 4     if 'prerequisites' in classes[course_code]:
#       5         # Get the raw string of prerequisites for the current course
#       6         prerequisites_str = classes[course_code]['prerequisites']
#       8         # Split the raw string into individual prerequisites
#
# KeyError: ''

# %%
print(f"Prerequisites for {course_code}: {prerequisites}")

# %%
def find_prerequisites(course_name, classes):
    # Check if the course has prerequisites 
    if 'prerequisites' in classes[course_name]:
        if classes[course_name] == '':
            # If prerequisites are empty, return nothing
            return ''
        else:
            # Get the raw string of prerequisites for the current course
            prerequisites_str = classes[course_name]['prerequisites']

            # Split the raw string into individual prerequisites
            prerequisites_list = [prerequisite.strip() for prerequisite in prerequisites_str.split('or')]

            # Initialize the list to store the complete set of prerequisites
            all_prerequisites = []

            # Process each branch separately
            for prerequisite in prerequisites_list:
                # Recursively find prerequisites for each branch
                branch_prerequisites = find_prerequisites(prerequisite, classes)
                # Add the current branch to the overall list
                all_prerequisites.append(branch_prerequisites)

            return all_prerequisites
    else:
        # If the course has no prerequisites, return an empty list
        return []

# %%
find_prerequisites('STAT 400', classes)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 find_prerequisites('STAT 400', classes)
#
# Cell In[50], line 20, in find_prerequisites(course_name, classes)
#      17 # Process each branch separately
#      18 for prerequisite in prerequisites_list:
#      19     # Recursively find prerequisites for each branch
# ---> 20     branch_prerequisites = find_prerequisites(prerequisite, classes)
#      21     # Add the current branch to the overall list
#      22     all_prerequisites.append(branch_prerequisites)
#
# Cell In[50], line 20, in find_prerequisites(course_name, classes)
#      17 # Process each branch separately
#      18 for prerequisite in prerequisites_list:
#      19     # Recursively find prerequisites for each branch
# ---> 20     branch_prerequisites = find_prerequisites(prerequisite, classes)
#      21     # Add the current branch to the overall list
#      22     all_prerequisites.append(branch_prerequisites)
#
#     [... skipping similar frames: find_prerequisites at line 20 (2 times)]
#
# Cell In[50], line 20, in find_prerequisites(course_name, classes)
#      17 # Process each branch separately
#      18 for prerequisite in prerequisites_list:
#      19     # Recursively find prerequisites for each branch
# ---> 20     branch_prerequisites = find_prerequisites(prerequisite, classes)
#      21     # Add the current branch to the overall list
#      22     all_prerequisites.append(branch_prerequisites)
#
# Cell In[50], line 3, in find_prerequisites(course_name, classes)
#       1 def find_prerequisites(course_name, classes):
#       2     # Check if the course has prerequisites
# ----> 3     if 'prerequisites' in classes[course_name]:
#       4         if classes[course_name] == '':
#       5             # If prerequisites are empty, return nothing
#       6             return ''
#
# KeyError: ''

# %%
# Example usage:
classes = {
    'STAT 400': {'prerequisites': 'MATH 141'},
    'MATH 141': {'prerequisites': 'MATH 140'},
    'MATH 140': {'prerequisites': 'MATH 108 or MATH 115'},
    'MATH 108': {'prerequisites': 'MATH 107'},
    'MATH 107': {'prerequisites': ''},
    'MATH 115': {'prerequisites': ''}
}

course_code = 'STAT 400'
prerequisites = find_prerequisites(course_code, classes)

print(f"Prerequisites for {course_code}: {prerequisites}")

# %%
from sqlalchemy import create_engine, Column, Integer, String, Sequence, Text, create_engine
from sqlalchemy.orm import declarative_base, Session

# Replace 'root' and 'rootroot' with your MySQL username and password
db_username = 'root'
db_password = 'root'
db_name = 'umgc'

# Create the MySQL engine
engine = create_engine(f'mysql+mysqlconnector://{db_username}:{db_password}@localhost/{db_name}')

Base = declarative_base()

# Define the Course class as a model
class Course(Base):
    __tablename__ = 'courses'

    id = Column(Integer, Sequence('course_id_seq'), primary_key=True)
    name = Column(String(20), unique=True)
    title = Column(String(100))
    credit = Column(String(5))
    description = Column(Text)
    prerequisites = Column(String(20))
    recommended = Column(String(20))
    warnings = Column(String(20))
    substitutions = Column(String(50))

# Create the table in the database
Base.metadata.create_all(engine)

# Data to be inserted into the 'courses' table
courses_data = [
    {'name': 'ACCT 221', 'title': 'Principles of Accounting II', 'credit': '3', 'description': '...', 'prerequisites': 'ACCT 220', 'recommended': '', 'warnings': '', 'substitutions': 'ACCT 221 or BMGT 221'},
    # Add more course data as needed
]

# Insert data into the 'courses' table
with Session(engine) as session:
    for course_info in courses_data:
        course = Course(**course_info)
        session.add(course)
    session.commit()

# %%
# Print the extracted information
for course in courses:
    print("=" * 50)
    print("Course Name:", course['name'])
    print("Course Title:", course['title'])
    print("Course Credit:", course['credit'])
    print("Course Prerequisites:", course['prerequisites'])
    print("Course Recommended:", course['recommended'])
    print("Course Warnings:", course['warnings'])
    print("Course Substitutions:", course['substitutions'])
    print("Course Description:")
    print(course['description'])
    print("=" * 50)
# Out:
# ==================================================
# Course Name: ACCT 220
# Course Title: Principles of Accounting I
# Course Credit: 3
# Course Prerequisites:
# Course Recommended:
# Course Warnings:
# Course Substitutions: ACCT 220 or BMGT 220
# Course Description:
# An introduction to the basic theory and techniques of contem-
# porary financial accounting. The objective is to identify the
# fundamental principles of accounting, identify and analyze
# business transactions, prepare financial statements, and com-
# municate this information to users with different needs. Topics
# include the accounting cycle, transactions, and the preparation
# of financial statements for single-owner business organizations
# that operate as service companies or merchandisers. Students
# may receive credit for only one of the following courses: ACCT
# 220 or BMGT 220.
#
# ==================================================
# ==================================================
# Course Name: ACCT 221
# Course Title: Principles of Accounting II
# Course Credit: 3
# Course Prerequisites: ACCT 220
# Course Recommended:
# Course Warnings:
# Course Substitutions: ACCT 221 or BMGT 221
# Course Description:
# Prerequisite: ACCT 220. Further study of contemporary account-
# ing practices, with an emphasis on data analysis for financial
# and managerial accounting. The goal is to analyze business
# transactions, define the characteristics of business entities,
# explain the interdependency of financial statements, employ
# managerial accounting techniques, and communicate this infor-
# mation to users with unique needs. Financial accounting topics
# include liabilities, equities, investments, and business entities.
# Managerial accounting topics include job order and process
# costing, cost-volume-profit analysis, and budgets. Students
# may receive credit for only one of the following courses: ACCT
# 221 or BMGT 221.
#
# ==================================================
# ==================================================
# Course Name: ACCT 301
# Course Title: Accounting for Nonaccounting Managers
# Course Credit: 3
# Course Prerequisites:
# Course Recommended:
# Course Warnings: May not be applied toward a major in accounting.
# Course Substitutions: ACCT 301, MGMT 301, or MGST 301
# Course Description:
# (May not be applied toward a major in accounting.) A survey of
# accounting principles relevant to making business decisions
# based on financial information. The aim is to apply critical-
# thinking skills and ethical principles to accounting issues.
# Topics include internal controls, financial reporting, financial
# statements analysis, managerial accounting, and budgeting
# elements. Students may receive credit for only one of the
# following courses: ACCT 301, MGMT 301, or MGST 301.
#
# ==================================================
# ==================================================
# Course Name: ACCT 310
# Course Title: Intermediate Accounting I
# Course Credit: 3
# Course Prerequisites: ACCT 221
# Course Recommended:
# Course Warnings: Students should be cautious about enrolling in ACCT 310 or ACCT 311. These are professional courses requiring intensive study and analysis and are not to be undertaken casually. Stu-dents who have not taken ACCT 221 within the last two years may have difficulty.
# Course Substitutions: ACCT 310 or BMGT 310
# Course Description:
# (Students should be cautious about enrolling in ACCT 310 or
# ACCT 311. These are professional courses requiring intensive
# study and analysis and are not to be undertaken casually. Stu-
# dents who have not taken ACCT 221 within the last two years
# may have difficulty.) Prerequisite: ACCT 221. A comprehensive
# analysis of financial accounting topics related to preparing finan-
# cial statements for external reporting. The objective is to analyze
# complex business transactions and their impact on financial
# statements. Focus is on researching and analyzing emerging
# issues in accounting, business transactions, and financing. Stu-
# dents may receive credit for only one of the following courses:
# ACCT 310 or BMGT 310.
#
# ==================================================
# ==================================================
# Course Name: ACCT 311
# Course Title: Intermediate Accounting II
# Course Credit: 3
# Course Prerequisites: ACCT 310
# Course Recommended:
# Course Warnings: A continuation of ACCT 310. Students should be cautious about enrolling in ACCT 310 or ACCT 311. These are professional courses requiring intensive study and analysis and are not to be undertaken casually. Students who have not taken ACCT 310 within the last two years may have difficulty.
# Course Substitutions: ACCT 311 or BMGT 311
# Course Description:
# (A continuation of ACCT 310. Students should be cautious about
# enrolling in ACCT 310 or ACCT 311. These are professional
# courses requiring intensive study and analysis and are not to
# be undertaken casually. Students who have not taken ACCT 310
# within the last two years may have difficulty.) Prerequisite: ACCT
# 310. A comprehensive analysis of financial accounting top-
# ics, including preparation of financial statements and external
# reports. The aim is to analyze complex business transactions
# and their impact on financial statements. Focus is on research-
# ing and analyzing emerging issues in accounting, business
# transactions, and financing. Students may receive credit for
# only one of the following courses: ACCT 311 or BMGT 311.
#
# ==================================================
# ==================================================
# Course Name: ACCT 320
# Course Title: Fraud Detection and Deterrence
# Course Credit: 3
# Course Prerequisites: ACCT 220 or ACCT 301
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisite: ACCT 220 or ACCT 301. A study of the principles
# behind and standards for examining, identifying, detecting,
# and deterring fraud. The objective is to differentiate types of
# fraud, assess organizational characteristics conducive to fraud,
# and develop a plan to detect and deter fraud. Topics include
# the fraud triangle, cash larceny, check tampering, skimming,
# register disbursement schemes, cash receipts schemes, billing
# schemes, payroll and expense reimbursement issues, asset
# misappropriations, corruption, accounting principles and fraud,
# fraudulent financial statements, whistleblowing, interviewing
# witnesses, and writing reports. Focus is on creating and com-
# municating meaningful data visualizations for stakeholders.
#
# ==================================================
# ==================================================
# Course Name: ACCT 321
# Course Title: Cost Accounting Data Analytics
# Course Credit: 3
# Course Prerequisites: ACCT 221
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisite: ACCT 221. A study of basic cost accounting con-
# cepts. The goal is to apply basic cost accounting concepts,
# use technology to prepare financial deliverables, evaluate
# business and financial data, and communicate financial infor-
# mation. Topics include ethics, corporate social responsibility,
# and the evaluation of business and financial data to make
# profit-maximizing decisions. Discussion also covers the role of
# accountants in decision-making; cost behavior; cost planning and
# control; and costing methods, such as standard costing, budget-
# ing, and inventory valuation. Focus is on using data analytics and
# creating and communicating meaningful data visualizations
# for decision-making.
#
# ==================================================
# ==================================================
# Course Name: ACCT 323
# Course Title: Federal Income Tax I
# Course Credit: 3
# Course Prerequisites: ACCT 220 or FINC 321
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisite: ACCT 220 or FINC 321. A study of data and
# processes related to the preparation of federal income tax for
# individuals and other entities. The objective is to explain the leg-
# islative process, conduct tax research, evaluate tax implications,
# and complete an individual tax return. Topics include the legisla-
# tive process, tax policy, research, and the evaluation of transac-
# tions and decisions for planning and compliance. Emphasis is
# on ethics and professional responsibilities.
#
# ==================================================
# ==================================================
# Course Name: ACCT 417
# Course Title: Federal Income Tax II
# Course Credit: 3
# Course Prerequisites: ACCT 311 and ACCT 323
# Course Recommended:
# Course Warnings: Strongly recommended for students seeking careers as CPAs.
# Course Substitutions: ACCT 417 or BMGT 417
# Course Description:
# (Strongly recommended for students seeking careers as CPAs.)
# Prerequisites: ACCT 311 and ACCT 323. A continuing study
# of federal income taxation as applied to different business
# entities, including corporations, flow-through entities, estates,
# and trusts. The aim is to analyze tax planning and compli-
# ance issues; conduct tax research; and analyze, evaluate, and
# communicate tax implications and data. Discussion covers tax
# research, planning, procedure, compliance, ethics, and profes-
# sional responsibility. Topics also include the tax implications of
# various entities’ financial and business decisions and transac-
# tions. Students may receive credit for only one of the following
# courses: ACCT 417 or BMGT 417.
#
# ==================================================
# ==================================================
# Course Name: ACCT 422
# Course Title: Auditing Theory and Practice
# Course Credit: 3
# Course Prerequisites: ACCT 311
# Course Recommended: ACCT 326
# Course Warnings:
# Course Substitutions: ACCT 422 or BMGT 422
# Course Description:
# Prerequisite: ACCT 311. Recommended: ACCT 326. A study of
# the auditing profession, audit process, and other assurance and
# non-assurance services related to the CPA profession. The objec-
# tive is to design an audit plan, apply audit procedures, evaluate
# audit findings, and assess the impact of standards and emerging
# issues. Topics include generally accepted auditing standards,
# tests of controls and substantive tests, statistical sampling,
# data analytics, report forms, and opinions. Various techniques
# are used to study auditing concepts and practices; these may
# include the use of problem sets, case studies, computer applica-
# tions, and other materials. Students may receive credit for only
# one of the following courses: ACCT 422 or BMGT 422.
#
# ==================================================
# ==================================================
# Course Name: ACCT 424
# Course Title: Advanced Accounting
# Course Credit: 3
# Course Prerequisites: ACCT 311
# Course Recommended:
# Course Warnings:
# Course Substitutions: ACCT 424 or BMGT 424
# Course Description:
# Prerequisite: ACCT 311. A study of advanced accounting theory,
# applied to specialized topics and contemporary problems. The
# aim is to prepare, present, and explain financial statements in
# five sectors—consolidated, international, partnership, not-for-
# profit, and state and local governments—and analyze a firm’s
# dissolution or reorganization. Emphasis is on consolidated
# statements and partnership accounting. Various techniques are
# used to study accounting theory and practice; these may include
# the use of data analytics, problem sets, case studies, computer
# applications, and other materials. Students may receive credit
# for only one of the following courses: ACCT 424 or BMGT 424.
#
# ==================================================
# ==================================================
# Course Name: ACCT 326
# Course Title: Accounting Information Systems
# Course Credit: 3
# Course Prerequisites: ACCT 221
# Course Recommended:
# Course Warnings:
# Course Substitutions: ACCT 326, BMGT 320, or BMGT 326
# Course Description:
# Prerequisite: ACCT 221. An introduction to accounting informa-
# tion systems (AIS) concepts. The objective is to evaluate how
# AIS tools are used to record, process, and analyze financial data;
# determine how best to integrate AIS tools and processes in a
# given organization; review and recommend controls to secure AIS
# applications and processes; and evaluate how technology can be
# used in AIS applications. Topics include transactional processing
# concepts and core AIS transactional cycles, basic control frame-
# works used to secure AIS applications and processes, strategies
# for implementing or upgrading AIS applications, information
# technology and accounting standards, and e-commerce and
# e-business. Students may receive credit for only one of the
# following courses: ACCT 326, BMGT 320, or BMGT 326.
#
# ==================================================
# ==================================================
# Course Name: ACCT 350
# Course Title: Federal Financial Management
# Course Credit: 3
# Course Prerequisites: ACCT 220 or ACCT 301
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisite: ACCT 220 or ACCT 301. Analysis and discussion
# of issues relating to federal financial management. The objec-
# tive is to apply knowledge of the federal process to accounting
# practice, administer federal grants and contracts, and research
# federal laws and regulations. Topics include the CFO Act, the
# federal budget, federal contracts and grants, data visualization
# presentations, and federal financial and information systems.
# Discussion also covers detection and deterrence of fraud,
# waste, and abuse.
#
# ==================================================
# ==================================================
# Course Name: ACCT 410
# Course Title: Accounting for Government and Not-for-Profit Organizations
# Course Credit: 3
# Course Prerequisites: ACCT 310
# Course Recommended:
# Course Warnings:
# Course Substitutions: ACCT 410 or BMGT 410
# Course Description:
# Prerequisite: ACCT 310. An introduction to the theory and
# practice of accounting as applied to governmental entities and
# not-for-profit organizations. The objective is to evaluate transac-
# tions, prepare and analyze financial statements, write financial
# briefings, prepare data visualization presentations, and apply
# accounting rules and procedures. Topics include the evaluation
# and preparation of reports required for governmental and not-
# for-profit entities. Students may receive credit for only one of
# the following courses: ACCT 410 or BMGT 410.
#
# ==================================================
# ==================================================
# Course Name: ACCT 411
# Course Title: Ethics and Professionalism in Accounting
# Course Credit: 3
# Course Prerequisites: ACCT 311
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisite: ACCT 311. An examination of ethical behavior in
# organizations and for the accounting and auditing professions.
# The goal is to identify ethical dilemmas, research regulations,
# and apply problem-solving methodology to resolve unethical
# situations. Discussion covers the AICPA Code of Professional
# Conduct and the ethical codes and requirements of other
# standard-setting organizations. Corporate governance, sustain-
# ability, and legal and regulatory obligations are explored within
# an ethical framework, including philosophical models and
# ethical theories, as well as within environmental, social, and
# governance (ESG) criteria.
#
# ==================================================
# ==================================================
# Course Name: ACCT 452
# Course Title: Federal Auditing
# Course Credit: 3
# Course Prerequisites: ACCT 221
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisite: ACCT 221. An overview of the federal auditing life
# cycle. The objective is to plan, manage, and execute a federal
# audit; identify and evaluate the program and financial risks;
# and identify and recommend enhancements to operations
# and technology. Topics include federal audits; data visualiza-
# tion, communicating audit findings to stakeholders, providing
# advisory support, and evaluating program and financial risks;
# managing technology and increasing economy and efficiency;
# and minimizing fraud, waste, and abuse. Discussions also cover
# the auditing of grants and contracts.
#
# ==================================================
# ==================================================
# Course Name: ACCT 486A
# Course Title: Workplace Learning in Accounting
# Course Credit: 3
# Course Prerequisites: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisites: 9 credits in the discipline and prior program
# approval (requirements detailed online at umgc.edu/wkpl). The
# integration of discipline-specific knowledge with new experi-
# ences in the work environment. Tasks include completing a
# series of academic assignments that parallel work experiences.
#
# ==================================================
# ==================================================
# Course Name: ACCT 486B
# Course Title: Workplace Learning in Accounting
# Course Credit: 6
# Course Prerequisites: 9 credits in the discipline and prior program approval (requirements detailed online at umgc.edu/wkpl)
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisites: 9 credits in the discipline and prior program
# approval (requirements detailed online at umgc.edu/wkpl). The
# integration of discipline-specific knowledge with new experi-
# ences in the work environment. Tasks include completing a
# series of academic assignments that parallel work experiences.
#
# ==================================================
# ==================================================
# Course Name: AASP 201
# Course Title: Introduction to African American Studies
# Course Credit: 3
# Course Prerequisites:
# Course Recommended:
# Course Warnings: Fulfills the general education requirement in behavioral and social sciences.
# Course Substitutions: AASP 100 or AASP 201
# Course Description:
# (Fulfills the general education requirement in behavioral and
# social sciences.) An interdisciplinary study of significant aspects
# of African American history and culture, emphasizing the devel-
# opment of African American communities from the Middle Pas-
# sage to the present. The objective is to conduct research, apply
# critical-thinking skills, and articulate diverse historical perspec-
# tives in the context of African American history and culture. Top-
# ics include definitions of African American identity, influences,
# and achievements within American culture, as well as issues
# confronting African Americans. Students may receive credit for
# only one of the following courses: AASP 100 or AASP 201.
#
# ==================================================
# ==================================================
# Course Name: ACCT 425
# Course Title: International Accounting
# Course Credit: 3
# Course Prerequisites: ACCT 311
# Course Recommended:
# Course Warnings:
# Course Substitutions: ACCT 425 or ACCT 498A
# Course Description:
# Prerequisite: ACCT 311. A study of accounting in a multinational
# context covering historical developments and international
# financial reporting standards. The objective is to recognize the
# influence of politics and culture on the development of account-
# ing systems, prepare financial statements according to inter-
# national financial reporting standards, and analyze the financial
# statements of a multinational enterprise. Strategies to manage
# and hedge against foreign currency exposure are developed.
# Topics include sustainability, foreign exchange and taxation,
# intercompany transfer pricing, data analytics, and emerging
# issues in international accounting. Students may receive credit
# for only one of the following courses: ACCT 425 or ACCT 498A.
#
# ==================================================
# ==================================================
# Course Name: ACCT 436
# Course Title: Internal Auditing
# Course Credit: 3
# Course Prerequisites: ACCT 311
# Course Recommended:
# Course Warnings: Designed to align with the standards of the Institute of Internal Auditors and help prepare for the Certified Internal Auditor exam-ination.
# Course Substitutions: ACCT 436, ACCT 498E, or BMGT 498E
# Course Description:
# (Designed to align with the standards of the Institute of Internal
# Auditors and help prepare for the Certified Internal Auditor exam-
# ination.) Prerequisite: ACCT 311. An exploration of the consulta-
# tive role in the management of risk. The aim is to identify the
# standards that apply to internal auditors, audit processes, and
# procedures and to assess internal control deficiencies. Topics
# include internal auditing standards, scope, responsibilities, eth-
# ics, controls, techniques, and reporting practices. Data analytics
# and practice involve the use of software such as Excel, Power BI,
# Tableau, ACL, and IDEA. Students may receive credit for only one
# of the following courses: ACCT 436, ACCT 498E, or BMGT 498E.
#
# ==================================================
# ==================================================
# Course Name: ACCT 438
# Course Title: Fraud and Forensic Accounting
# Course Credit: 3
# Course Prerequisites: ACCT 311
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisite: ACCT 311. An analysis and discussion of issues
# relating to fraud and forensic accounting. The objective is to
# identify the resources for detecting fraud, evaluate the condi-
# tions that encourage fraud, and design effective fraud detection
# and deterrence plans. Discussion covers the principles and
# standards for proactive and reactive investigation, as well as
# detection and control of fraud. Focus is on data analytics and
# creating and communicating meaningful data visualizations
# for stakeholders from the perspective of public, internal, and
# private accountants.
#
# ==================================================
# ==================================================
# Course Name: ACCT 440
# Course Title: Forensic and Investigative Accounting
# Course Credit: 3
# Course Prerequisites: ACCT 320 or ACCT 438
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisite: ACCT 320 or ACCT 438. An analysis and discus-
# sion of issues relating to forensic and investigative account-
# ing. The goal is to research and describe the use of forensic
# accounting evidence, identify the role of the forensic accoun-
# tant, apply investigative and forensic accounting practices, and
# present forensic accounting evidence as an expert witness.
# Forensic and investigative methods, including the use of data
# analytics, auditing, and technology are demonstrated. Topics
# include criminal and civil litigation support, rules of evidence,
# and accreditation of expert witnesses.
#
# ==================================================
# ==================================================
# Course Name: ANTH 101
# Course Title: Introduction to Biological Anthropology
# Course Credit: 3
# Course Prerequisites:
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# A survey of general patterns in the development of human
# culture, addressing the biological and morphological aspects
# of humans viewed in their cultural setting. The aim is to apply
# anthropological knowledge to understanding human origins and
# how human populations adapt to the environment. Discussion
# examines human evolution and adaptation, including biocultural
# patterns in humans and other primates. Students who complete
# both ANTH 101 and ANTH 102 may not receive credit for ANTH
# 340, BEHS 340, or BEHS 341.
#
# ==================================================
# ==================================================
# Course Name: ANTH 102
# Course Title: Introduction to Cultural Anthropology
# Course Credit: 3
# Course Prerequisites:
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# A survey of social and cultural principles inherent in ethno-
# graphic descriptions. The objective is to apply anthropological
# knowledge of human behavior to everyday situations and prob-
# lems. Students who complete both ANTH 101 and ANTH 102
# may not receive credit for ANTH 340, BEHS 340, or BEHS 341.
#
# ==================================================
# ==================================================
# Course Name: ANTH 298
# Course Title: Special Topics in Anthropology
# Course Credit: 1–3
# Course Prerequisites:
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# A presentation of anthropological perspectives on selected top-
# ics of broad general interest. May be repeated to a maximum of
# 6 credits when topics differ.
#
# ==================================================
# ==================================================
# Course Name: ANTH 345
# Course Title: World Prehistory and Archaeology
# Course Credit: 3
# Course Prerequisites:
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# An intermediate-level exploration of world prehistory and
# archaeology. The goal is to analyze the cultural, technological,
# and subsistence patterns of prehistoric humans and relate
# these patterns to contemporary human societies and popula-
# tions. Discussion covers archaeological theories and methods;
# subsistence strategies; and the applications of archaeological
# knowledge to modern community, regional, and global issues.
#
# ==================================================
# ==================================================
# Course Name: ANTH 346
# Course Title: Anthropology of Language and Communication
# Course Credit: 3
# Course Prerequisites:
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# An intermediate-level anthropological study of language, com-
# munication, and culture. The aim is to understand language in
# a cultural context; assess how the concepts, approaches, and
# methods of linguistic anthropology explain communication in
# changing cultural environments; and recognize how language
# both shapes and is shaped by culture. Topics include the origin
# of human language, linguistic diversity, structural elements
# of verbal and nonverbal language, language as social action,
# research in anthropological linguistics, language and power
# hierarchies, gendered communications, and linguistic diversity
# in the contemporary world.
#
# ==================================================
# ==================================================
# Course Name: ANTH 350
# Course Title: Health, Illness, and Healing
# Course Credit: 3
# Course Prerequisites:
# Course Recommended: ANTH 102
# Course Warnings:
# Course Substitutions:
# Course Description:
# Recommended: ANTH 102. An overview of health, illness, and
# healing from a cross-cultural perspective. The objective is to
# apply the perspectives of medical anthropology to promote indi-
# vidual and public health in local, national, and global contexts.
# Topics include cultural and social influences on health and heal-
# ing, the experience and meaning of illness, and current issues in
# public and global health.
#
# ==================================================
# ==================================================
# Course Name: ANTH 351
# Course Title: Anthropology in Forensic Investigations
# Course Credit: 3
# Course Prerequisites:
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# An overview of forensic anthropology, an applied field of anthro-
# pology that seeks to recover, identify, and evaluate human skel-
# etal remains within a medicolegal context. The aim is to explore
# the processes and methods used by forensic anthropologists to
# identify a cause and manner of death and determine an approxi-
# mate postmortem interval. Topics include the forensic context,
# the human skeletal system, methods of identification, cause
# and manner of death, assessment of trauma, and analysis of
# evidence to draw conclusions about a case.
#
# ==================================================
# ==================================================
# Course Name: ANTH 398
# Course Title: Intermediate Special Topics in Anthropology
# Course Credit: 1–3
# Course Prerequisites:
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# A presentation of anthropological perspectives on selected top-
# ics of broad general interest. May be repeated to a maximum of
# 6 credits when topics differ.
#
# ==================================================
# ==================================================
# Course Name: ANTH 417
# Course Title: Peoples and Cultures of East Asia
# Course Credit: 3
# Course Prerequisites:
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# An advanced anthropological study of the peoples and cultures
# of East Asia, focusing on China, Japan, and Korea. The aim is
# to apply anthropological theories and methods to the inter-
# pretation of contemporary East Asian cultures, relate family
# structure to individual choices and social interactions in East
# Asian cultures, and analyze how ethnic and national identities
# and regional differences affect regional and global interactions.
# Topics include urbanization, social values, social change, and
# the role of East Asia in the modern world.
#
# ==================================================
# ==================================================
# Course Name: APTC 495
# Course Title: Applied Technology Capstone
# Course Credit: 3
# Course Prerequisites: 27 credits in major coursework
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisites: 27 credits in major coursework. A project-based
# application of computing knowledge and skills to solve prob-
# lems. Focus is on researching, planning, and implementing
# a computing-based solution to an approved business and
# disciplinary-based problem outside the primary area of tech-
# nology or computing focus. Assignments include working in
# teams through the planning, analysis, design, implementa-
# tion, testing, and documentation phases. A presentation of the
# applied solutions constitutes a final learning demonstration.
#
# ==================================================
# ==================================================
# Course Name: ARAB 111
# Course Title: Elementary Arabic I
# Course Credit: 3
# Course Prerequisites:
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# For online sections, microphone, speakers, and occasional
# synchronous work required. (Not open to native speakers of Ara-
# bic; assumes no prior knowledge of Arabic. Students with prior
# experience with the Arabic language should take a placement
# test to assess appropriate level.) An introduction to spoken
# and written modern standard Arabic. The objective is to com-
# municate in Arabic in some concrete, real-life situations, using
# culturally appropriate language and etiquette. Ample practice
# in Arabic pronunciation and the structures needed for everyday
# communication are provided.
#
# ==================================================
# ==================================================
# Course Name: ARAB 112
# Course Title: Elementary Arabic II
# Course Credit: 3
# Course Prerequisites: ARAB 111 or appropriate score on a placement test
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# For online sections, microphone, speakers, and occasional
# synchronous work required. (Not open to native speakers of
# Arabic; assumes no prior knowledge of Arabic. Students with
# prior experience with the Arabic language should take a place-
# ment test to assess appropriate level.) Prerequisite: ARAB 111
# or appropriate score on a placement test. An introduction to
# spoken and written modern standard Arabic. The objective is
# to communicate in Arabic in some concrete, real-life situations,
# using culturally appropriate language and etiquette. Ample
# practice in Arabic pronunciation and the structures needed for
# everyday communication are provided.
#
# ==================================================
# ==================================================
# Course Name: ARAB 114
# Course Title: Elementary Arabic III
# Course Credit: 3
# Course Prerequisites: ARAB 112 or appropriate score on a placement test
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# For online sections, microphone, speakers, and occasional
# synchronous work required. (Not open to native speakers
# of Arabic.) Prerequisite: ARAB 112 or appropriate score on a
# placement test. Further development of skills in elementary
# spoken and written modern standard Arabic. The aim is to com-
# municate in Arabic in a variety of real-life situations, using cul-
# turally appropriate language. Practice is provided in improving
# pronunciation and developing the oral and written skills used
# in everyday communication.
#
# ==================================================
# ==================================================
# Course Name: ARAB 115
# Course Title: Elementary Arabic IV
# Course Credit: 3
# Course Prerequisites: ARAB 114 or appropriate score on a place-ment test
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# For online sections, microphone, speakers, and occasional
# synchronous work required. (Not open to native speakers of
# Arabic.) Prerequisite: ARAB 114 or appropriate score on a place-
# ment test. Further development of skills in elementary spoken
# and written modern standard Arabic. The objective is to interact
# effectively with native Arabic speakers in a variety of real-life
# situations, using culturally appropriate language. Practice in
# fine-tuning pronunciation and applying language skills to a
# range of contexts is provided.
#
# ==================================================
# ==================================================
# Course Name: ARAB 333
# Course Title: Middle Eastern Cultures
# Course Credit: 3
# Course Prerequisites:
# Course Recommended:
# Course Warnings: Conducted in English.
# Course Substitutions: ARAB 333 or ARAB 334
# Course Description:
# (Conducted in English.) A project-driven and discussion-based
# study of Middle Eastern cultures. The aim is to demonstrate
# cultural competence by explaining and analyzing Middle East-
# ern cultures through a variety of perspectives. Topics include
# religion, cultural practices, history, geography, and societies of
# the Middle East. Students may receive credit for only one of the
# following courses: ARAB 333 or ARAB 334.
#
# ==================================================
# ==================================================
# Course Name: ARTT 110
# Course Title: Introduction to Drawing
# Course Credit: 3
# Course Prerequisites:
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# A hands-on introduction to various drawing media and related
# techniques. The objective is to translate the three-dimensional
# world into two dimensions, communicate through a visual
# medium, and critique visual works of art. Projects are based
# on nature and still life.
#
# ==================================================
# ==================================================
# Course Name: ARTT 120
# Course Title: Design I: Arrangement and Color
# Course Credit: 3
# Course Prerequisites: GRCO 100
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisite: GRCO 100. A project-driven study of the design ele-
# ments of a composition as they relate to its overall expression.
# The aim is to apply elements and principles of design, including
# color theory, to create a variety of compositions that effectively
# communicate ideas and emotions.
#
# ==================================================
# ==================================================
# Course Name: ARTT 152
# Course Title: Basics of Photography
# Course Credit: 3
# Course Prerequisites:
# Course Recommended:
# Course Warnings: Access to a digital camera with manual settings required.
# Course Substitutions: ARTT 152 or PHOT 198
# Course Description:
# (Access to a digital camera with manual settings required.) An
# introduction to basic photographic procedures with an empha-
# sis on composing, taking, and editing photographs. Discussion
# covers the historical development of photography. Students
# may receive credit for only one of the following courses:
# ARTT 152 or PHOT 198.
#
# ==================================================
# ==================================================
# Course Name: ARTT 210
# Course Title: Intermediate Drawing
# Course Credit: 3
# Course Prerequisites: ARTT 110
# Course Recommended:
# Course Warnings:
# Course Substitutions: ARTS 210 or ARTT 210
# Course Description:
# Prerequisite: ARTT 110. A continuing examination of materials
# and techniques of drawing. The objective is to apply drawing
# techniques and visual principles to various subjects, communi-
# cate through drawing, and critique works of art. More advanced
# media, compositions, techniques, and subjects are explored.
# Students may receive credit for only one of the following
# courses: ARTS 210 or ARTT 210.
#
# ==================================================
# ==================================================
# Course Name: ARTT 320
# Course Title: Painting
# Course Credit: 3
# Course Prerequisites: ARTT 110
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisite: ARTT 110. Practice in the basic tools and vocabu-
# lary of painting. The goal is to apply an understanding of com-
# positional strategies, visual principles, and basic materials
# and techniques to produce paintings using oil/watercolor/
# acrylic paints.
#
# ==================================================
# ==================================================
# Course Name: ARTT 428
# Course Title: Advanced Painting
# Course Credit: 3
# Course Prerequisites: ARTT 320
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisite: ARTT 320. Creation of original compositions based
# on the figure, nature, and still life, as well as expressive painting.
# The goal is to paint in a variety of styles and techniques, work
# with more complex forms (including drapery, transparency, and
# reflections), and work in landscape and/or figure in space paint-
# ing. Emphasis is on the development of personal directions.
# May be repeated to a maximum of 12 credits.
#
# ==================================================
# ==================================================
# Course Name: ARTH 204
# Course Title: Film and American Culture Studies
# Course Credit: 3
# Course Prerequisites:
# Course Recommended:
# Course Warnings:
# Course Substitutions: ARTH 204, AMST 204, or HUMN 204
# Course Description:
# An introductory study of the relationship between film and
# American culture. The objective is to improve one’s ability
# to understand a film’s message and to expand one’s cultural
# awareness. Discussion covers the way one of our most popular
# media portrays American culture and influences our interpreta-
# tion of cultural issues. Various films, filmmaking issues, and
# representative filmmakers’ work are examined. Students may
# receive credit for only one of the following courses: ARTH 204,
# AMST 204, or HUMN 204.
#
# ==================================================
# ==================================================
# Course Name: ARTH 334
# Course Title: Understanding Movies
# Course Credit: 3
# Course Prerequisites:
# Course Recommended:
# Course Warnings: Formerly HUMN 334.
# Course Substitutions: ARTH 334, HUMN 334,  or HUMN 498D
# Course Description:
# (Formerly HUMN 334.) An analysis of one of the most important
# means of artistic expression of the 20th century. The goal is to
# acquire a deeper understanding of the aesthetic qualities of film
# by considering the stylistic elements of film as it has evolved
# throughout the century and weighing the special relationship
# between cinema and literature. Students may receive credit
# for only one of the following courses: ARTH 334, HUMN 334,
# or HUMN 498D.
#
# ==================================================
# ==================================================
# Course Name: ARTH 372
# Course Title: History of Western Art I
# Course Credit: 3
# Course Prerequisites:
# Course Recommended:
# Course Warnings: Formerly ARTH 370.
# Course Substitutions: ARTH 370 or ARTH 372
# Course Description:
# (Formerly ARTH 370.) A survey of the development of the
# Western tradition of visual art in its various forms that exam-
# ines and compares the expression of cultural and aesthetic
# values in different parts of the Western world from prehistory
# through the Middle Ages. The objective is to apply principles of
# visual literacy; describe, analyze, and contextualize content and
# elements of art; and differentiate historic periods and styles of
# art. Students may receive credit for only one of the following
# courses: ARTH 370 or ARTH 372.
#
# ==================================================
# ==================================================
# Course Name: ARTH 373
# Course Title: History of Western Art II
# Course Credit: 3
# Course Prerequisites:
# Course Recommended:
# Course Warnings: Formerly ARTH 371.
# Course Substitutions: ARTH 371 or ARTH 373
# Course Description:
# (Formerly ARTH 371.) A survey of the development of visual
# art of the Western world in its various forms that examines and
# compares the expression of cultural and aesthetic values in
# Europe and the United States from 1300 to the present day. The
# aim is to apply principles of visual literacy; describe, analyze,
# and contextualize content and elements of art; and differentiate
# historic periods and styles of art. Students may receive credit
# for only one of the following courses: ARTH 371 or ARTH 373.
#
# ==================================================
# ==================================================
# Course Name: ARTH 375
# Course Title: History of Graphic Art
# Course Credit: 3
# Course Prerequisites:
# Course Recommended: ARTH 204
# Course Warnings:
# Course Substitutions:
# Course Description:
# Recommended: ARTH 204. A survey of the development of
# graphic design with an emphasis on the historical, technologi-
# cal, and sociological influences on the production of typography
# and the aesthetics of visual media. The aim is to recognize the
# philosophy of graphic arts, identify various movements within
# the field, and analyze the impact of graphic arts on society.
# Topics include major works and artists and cultural, social,
# and religious movements and their impact on graphic arts.
#
# ==================================================
# ==================================================
# Course Name: ARTH 478
# Course Title: History of Women in the Visual Arts
# Course Credit: 3
# Course Prerequisites:
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# A survey of the work, roles, and representations of women in
# the visual arts, from the 16th century to the present. The aim
# is to evaluate the role of women artists and assess the impact
# of gender on visual arts as a way to understand the complexity
# and diversity of human experience and culture. Emphasis is on
# women working in the tradition of Western art in painting, sculp-
# ture, the decorative arts, performance art, photography, and other
# media and on how gender affected their art and their careers.
#
# ==================================================
# ==================================================
# Course Name: ASTD 135
# Course Title: Introduction to Japanese Language and Culture
# Course Credit: 3
# Course Prerequisites:
# Course Recommended:
# Course Warnings: Formerly JAPN 105. Not open to students with substantial prior experience with Japanese language or culture; assumes no prior knowledge of Japanese. Students with prior experience with the Japanese language should take a placement test to assess appropriate level.
# Course Substitutions: ASTD 135 or JAPN 105
# Course Description:
# (Formerly JAPN 105. Not open to students with substantial
# prior experience with Japanese language or culture; assumes
# no prior knowledge of Japanese. Students with prior experience
# with the Japanese language should take a placement test to
# assess appropriate level.) A hands-on, project-based introduc-
# tion to Japanese language and culture. The goal is to develop
# cultural competency and familiarity with the history, geography,
# and culture of Japan and to use basic language skills to func-
# tion effectively and appropriately in everyday life in Japan. Stu-
# dents may receive credit for only one of the following courses:
# ASTD 135 or JAPN 105.
#
# ==================================================
# ==================================================
# Course Name: ASTD 155
# Course Title: Introduction to Korean Language and Culture
# Course Credit: 3
# Course Prerequisites:
# Course Recommended:
# Course Warnings: Not open to students with substantial prior experience with Korean language or culture; assumes no prior knowledge of Korean. Students with prior experience with the Korean language should take a placement test to assess appropriate level.
# Course Substitutions: ASTD 155 or KORN 105
# Course Description:
# (Not open to students with substantial prior experience with
# Korean language or culture; assumes no prior knowledge
# of Korean. Students with prior experience with the Korean
# language should take a placement test to assess appropriate
# level.) A hands-on, project-based introduction to Korean lan-
# guage and culture. The goal is to develop cultural competence
# in personal interactions; demonstrate knowledge of the history,
# geography, and culture of Korea; and use basic language skills
# to function effectively and appropriately in everyday activities in
# Korea. Students may receive credit for only one of the following
# courses: ASTD 155 or KORN 105.
#
# ==================================================
# ==================================================
# Course Name: ASTD 284
# Course Title: Foundations of East Asian Civilization
# Course Credit: 3
# Course Prerequisites:
# Course Recommended:
# Course Warnings: Formerly HIST 284.
# Course Substitutions: ASTD 150, ASTD 284,  or HIST 284
# Course Description:
# (Formerly HIST 284.) An interdisciplinary survey of the foun-
# dations of East Asian civilization from its beginnings to the
# 17th century. The goal is to analyze philosophical, religious,
# artistic, economic, and political aspects of the region’s historical
# experience. Focus is on China, Korea, and Japan. Topics include
# East Asian belief systems (including Confucianism and Bud-
# dhism), the dynastic cycle, relations between steppe and agrar-
# ian societies, warrior and scholar-gentry cultures, technological
# change and economic development, and the role of class and
# gender in early East Asian society. Students may receive credit
# for only one of the following courses: ASTD 150, ASTD 284,
# or HIST 284.
#
# ==================================================
# ==================================================
# Course Name: ASTD 285
# Course Title: Introduction to Modern East Asia
# Course Credit: 3
# Course Prerequisites:
# Course Recommended:
# Course Warnings: Formerly HIST 285.
# Course Substitutions: ASTD 160, ASTD 285, or HIST 285
# Course Description:
# (Formerly HIST 285.) An interdisciplinary survey of East Asia
# from the late 17th century—beginning with Ming-Qing China,
# Tokugawa Japan, and Choson Korea—to the present. The objec-
# tive is to trace how transformations on global, regional, and
# local levels led to the development of the modern nation-states
# of East Asia and to examine how those developments affected
# the culture of the areas. Topics include the rise of imperial-
# ism and colonialism; cross-cultural interactions; and issues of
# gender, class, and ethnicity in East Asian culture. Students may
# receive credit for only one of the following courses: ASTD 160,
# ASTD 285, or HIST 285.
#
# ==================================================
# ==================================================
# Course Name: ASTD 302
# Course Title: The Two Koreas: Problems and Prospects
# Course Credit: 3
# Course Prerequisites: Any writing course
# Course Recommended: ASTD 284 or ASTD 285
# Course Warnings:
# ...
# Course Credit: 3
# Course Prerequisites: SWEN 646
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisite: SWEN 646. An exploration of software design and
# implementation for reducing complexity of systems. Topics
# include software design patterns, object-oriented programming,
# and aspect-oriented programming design. Focus is on building
# software products using these technologies.
#
# ==================================================
# ==================================================
# Course Name: SWEN 661
# Course Title: User Interface Implementation
# Course Credit: 3
# Course Prerequisites: SWEN 651
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisite: SWEN 651. An examination of all types of user
# interfaces. Topics include developing user interfaces using
# mobile, desktop, and web technologies. Focus is on building
# user interfaces using these technologies.
#
# ==================================================
# ==================================================
# Course Name: SWEN 670
# Course Title: Software Engineering Capstone
# Course Credit: 3
# Course Prerequisites: 30 credits of program coursework, including all core courses
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisite: 30 credits of program coursework, including all
# core courses. A comprehensive examination of the tools, skills,
# and techniques of software engineering and their application.
# Completion of a major team project is designed to integrate
# knowledge and skills gained through previous study and provide
# experience of the constraints commonly experienced in industry
# (scheduling, vagueness of clients). Project requires forming
# teams (organization) and scheduling work to meet the deadlines
# imposed by the contract (syllabus).
#
# ==================================================
# ==================================================
# Course Name: UCSP 615
# Course Title: Orientation to Graduate Studies at UMGC (0) MSC 610 Foundations of Strategic Communications
# Course Credit: 6
# Course Prerequisites: DCL 600M
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisite: DCL 600M. Acquire foundational skills in strategic
# communications, including effective writing targeted to different
# audiences and media; fundamental research; and the planning,
# execution, and assessment of a communications plan. Become
# familiar with the public relations, marketing, and advertising
# industries and their practices; theoretical and ethical founda-
# tions; and the role of strategic communications in each.
#
# ==================================================
# ==================================================
# Course Name: MSC 620
# Course Title: Communications Techniques and Tactics
# Course Credit: 6
# Course Prerequisites: MSC 610
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisite: MSC 610. Develop internal and external com-
# munications strategies and select and produce appropriate
# communications tactics to execute them. Create internal com-
# munications that focus on employee engagement, leadership,
# and change management. Exercise best practices in media
# relations and social media product development.
#
# ==================================================
# ==================================================
# Course Name: MSC 630
# Course Title: Communications Leadership and Management
# Course Credit: 6
# Course Prerequisites: MSC 620
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisite: MSC 620. Practice advanced strategic communi-
# cations decision-making in both national and international con-
# texts. Coordinate public relations efforts internally, particularly
# between marketing and advertising departments. Master funda-
# mental financial accounting and budgeting concepts required
# for many communications campaigns in business, government,
# and the nonprofit sectors. Align communications campaigns
# with organizational objectives. Follow global strategic commu-
# nications trends and legal and ethical issues.
#
# ==================================================
# ==================================================
# Course Name: MSC 640
# Course Title: Crisis Communications Management
# Course Credit: 6
# Course Prerequisites: MSC 630
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisite: MSC 630. Develop strategic responses, including
# crisis definition, issue management, and crisis communications
# management, to crisis situations. Apply crisis communication
# theory and implement risk communication and reputation and
# image restoration best practices. Utilize appropriate research
# methods to inform a crisis communications plan.
#
# ==================================================
# ==================================================
# Course Name: MSC 670
# Course Title: Capstone: Communications Campaigns
# Course Credit: 6
# Course Prerequisites: MSC 640
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisite: MSC 640. Assume the role of a corporate com-
# munications director and create a communications plan to
# support an organizational strategy for an existing organization.
# Conduct research; develop a problem statement; and identify
# campaign goals and objectives, audience segments, and mes-
# saging targeted to those segments. Create a communications
# strategy with tactics and timelines, evaluation plans, and a
# realistic budget.
#
# ==================================================
# ==================================================
# Course Name: SYSE 610
# Course Title: Systems Engineering Overview
# Course Credit: 3
# Course Prerequisites:
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# An introduction to systems engineering using examples of man-
# ufacturing, information, and mechanical systems that involve
# the integration of different technologies. Emphasis is on the
# role of the systems engineer. Systems thinking principles and
# complex systems and system-of-systems theory are reviewed.
# Discussion covers various approaches to system dynamics
# modeling. An overview of the system life cycle through con-
# ception, design and development, integration and testing, and
# deployment and support is provided.
#
# ==================================================
# ==================================================
# Course Name: SYSE 620
# Course Title: Requirements Engineering
# Course Credit: 3
# Course Prerequisites:
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# An in-depth examination of the various techniques used in
# establishing and specifying system requirements, both physical
# and functional. Topics include system decomposition, require-
# ments traceability, configuration management, and require-
# ments validation. Several U.S. and international standards
# are examined as examples of requirements specification.
#
# ==================================================
# ==================================================
# Course Name: SYSE 625
# Course Title: Model-Based Systems Engineering
# Course Credit: 3
# Course Prerequisites: SYSE 610
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisite: SYSE 610. An introduction to formal system model-
# ing and simulation methods using software-based approaches,
# which are replacing more traditional document-based descrip-
# tive modeling methods. Discussion covers the trend in industry
# toward standardized modeling techniques using software,
# especially SysML (Systems Modeling Language) computer
# packages, allowing greater consistency in system model repre-
# sentations between technologies, across industries, and even
# across language barriers. Topics include ways that computers
# can represent system models in detail and provide complex
# system simulations with minimum effort using several differ-
# ent system modeling and simulation software platforms. The
# objective is to be able to determine when and how model-based
# systems engineering (MBSE) approaches are useful, which tools
# to use, and which data to use as input to the MBSE tools and
# how to use the results from the tools in decision-making.
#
# ==================================================
# ==================================================
# Course Name: SYSE 630
# Course Title: System Design and Development
# Course Credit: 3
# Course Prerequisites: SYSE 610 and SYSE 620
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisites: SYSE 610 and SYSE 620. A detailed exploration
# of the design and development phases of the system life cycle.
# Discussion covers several tools used for systems simulation
# and computer-aided design. Topics also include methods and
# policies for change control and the principles of quality assur-
# ance as an underlying concept in systems design.
#
# ==================================================
# ==================================================
# Course Name: SYSE 640
# Course Title: System Integration and Test
# Course Credit: 3
# Course Prerequisites: SYSE 610 and SYSE 620
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisites: SYSE 610 and SYSE 620. A review of various
# strategies used to integrate system components and verify
# satisfaction of requirements at both subsystem and overall
# system levels. The concept of formal verification, validation,
# and accreditation (VV&A) is discussed. Examples of automated
# software testing tools are also examined.
#
# ==================================================
# ==================================================
# Course Name: SYSE 650
# Course Title: Design Considerations
# Course Credit: 3
# Course Prerequisites: SYSE 610 and SYSE 620
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisites: SYSE 610 and SYSE 620. An introduction to sys-
# tem engineering subdisciplines that are critical in system design
# and deployment. Discussion covers reliability, availability, and
# maintainability (RAM) factors. Concepts in human factors engi-
# neering, system safety, and quality assurance are also reviewed.
#
# ==================================================
# ==================================================
# Course Name: SYSE 660
# Course Title: Systems Engineering Management
# Course Credit: 3
# Course Prerequisites: SYSE 630 and SYSE 640
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisites: SYSE 630 and SYSE 640. An examination of
# the role played by the systems engineer as liaison between
# technical specialists, business managers, and internal users or
# external customers. Discussion covers the traditional systems
# development life cycle, domestic and internal standards, and the
# evolving emphasis on agile methods and adaptive processes.
# Topics also include risk management and organizational consid-
# erations in outsourcing.
#
# ==================================================
# ==================================================
# Course Name: SYSE 670
# Course Title: Systems Engineering Capstone
# Course Credit: 3
# Course Prerequisites: SYSE 640 and SYSE 650
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisites: SYSE 640 and SYSE 650. A project-based
# capstone study of systems engineering designed to integrate
# knowledge and skills gained in previous study. Both individual
# projects and a group project focus on demonstrating the ability
# to construct a system design and develop a plan for a system’s
# development and support.
#
# ==================================================
# ==================================================
# Course Name: TLP 610
# Course Title: Repositioning Your Leadership Skills
# Course Credit: 6
# Course Prerequisites: DCL 600M
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisite: DCL 600M. Master the ways in which leader-
# ship takes place within organizations and the most effective
# leadership styles for directing individuals, projects, and groups
# to success. Demonstrate the differences between managing
# and leading, focusing on motivating and inspiring individuals
# in preparation for future challenges and opportunities. Explore
# the various roles that leaders take on in domestic and global
# markets and the ways leaders influence events that can drive
# success through individual and collaborative efforts. Create
# your own personal brand as you begin a journey to becoming
# a transformational leader.
#
# ==================================================
# ==================================================
# Course Name: TLP 620
# Course Title: Leading in the Organization
# Course Credit: 6
# Course Prerequisites: TLP 610
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisite: TLP 610. Analyze the dynamics involved in leading
# a workforce of multigenerational and diverse talent. Develop
# strategies for facilitating an inclusive work culture and maximiz-
# ing the varied skill sets and experiences of employees. Weigh
# the impact of workforce change on organizations and consider
# the potential challenges that run counter to respectful, civil, and
# ethical work environments. Create retention and succession
# planning strategies and techniques for coaching and mentoring
# emerging leaders.
#
# ==================================================
# ==================================================
# Course Name: TLP 630
# Course Title: Leading with Strategy and Performance Measures
# Course Credit: 6
# Course Prerequisites: TLP 620
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisite: TLP 620. Gain the tools to assess the organiza-
# tion’s bottom line and action steps for growth and sustainability.
# Apply strategic management theories and practice to measure
# and motivate organizational performance, identify trends,
# and direct the different stages of the organization’s life cycle.
# Become proficient using tools to review and interpret analytics,
# market research, and financial data that can drive short- and
# long-range strategic decisions and identify potential deficien-
# cies that run counter to the organization’s mission and goals.
#
# ==================================================
# ==================================================
# Course Name: TLP 640
# Course Title: Leading Through Change and Uncertainty
# Course Credit: 6
# Course Prerequisites: TLP 630
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisite: TLP 630. Apply change management techniques
# for leading and maintaining stability during unplanned, turbulent
# events within the organization. Analyze and implement stra-
# tegic planning and decision-making approaches to diagnose
# the symptoms and predictors of organizational challenges
# and obstacles to change. Use change management models to
# assess organizational performance and process reengineer-
# ing and to forecast outcomes and resistance to change at the
# individual, group, and organization levels.
#
# ==================================================
# ==================================================
# Course Name: TLP 670
# Course Title: Leadership Capstone
# Course Credit: 6
# Course Prerequisites: TLP 640
# Course Recommended:
# Course Warnings:
# Course Substitutions:
# Course Description:
# Prerequisite: TLP 640. Lead a real-world consulting project.
# Apply the techniques of project management as you collabo-
# rate with a partnering organization to develop a strategic and
# financial plan to address an organizational issue. Use client-
# relationship management, organizational diagnosis models,
# and coaching and presentation skills to complete your consult-
# ing project and showcase your solutions and plans to your
# partner organization.
#
# ==================================================

# %% [markdown]
# # Add courses to DB

# %%
import mysql.connector

# %%
# Connection details (later learn how to not include password here)
config = {
    'unix_socket': '/tmp/mysql.sock',
    'user': 'root',
    'password': 'root',
    'database': 'umgc',
}

# %% [markdown]
# # Debug

# %% [markdown]
# ### Debug inner loop

# %%
courses = parse_course_info(test_text)

# %%
courses[0]

# %%
courses[1]

# %% [markdown]
# ## Above is not working correctly. Not separating ANTH 298 and ANTH 345.
# ### Debugging below

# %% [markdown]
# #### Inner Loop

# %% [markdown]
# ### End description debug

# %%
# Establish the connection
connection = mysql.connector.connect(**config)

# Create a cursor for executing queries
cursor = connection.cursor()

# Now you can execute queries using the cursor

# Remember to close the cursor and connection when done
cursor.close()
connection.close()

# %% [markdown]
# # Archive of Prior Functions (Skip Now)

# %%
def parse_course_info_works(text):
    courses = []
    prior_course = None
    current_course = None
    start_course = False
    warnings = None
    prereq = False

    # Define regular expressions for extracting information
    course_pattern = re.compile(r'^([A-Z]{4} \d{3}[A-Z]?) ([A-Z].+?) \((\d-?\d?)\)$')
    course_start_pattern = re.compile(r'^([A-Z]{4} \d{3}[A-Z]?) ([A-Z].+?)$')
    course_end_pattern = re.compile(r'^(.+?) \((\d-?\d?)\)$')    
    end_pattern = re.compile(r'^COURSE INFORMATION')

    # Define prerequisite regular expression patterns to capture the desired text
    prereq_oneline = re.compile(r'Prerequisite: (.+?)\.')
    prereq_start = re.compile(r'Prerequisite: (.+)$')
    prereq_end = re.compile(r'^(.+)\.')
    
    # Define substitutions regular expression pattern
    substitutions_pattern = re.compile(r'Students\s+may\s+receive\s+credit\s+for\s+only\s+one\s+of\s+the\s+following\s+courses: ')

    for line in text.split('\n'):

        end_match = end_pattern.match(line)
        course_match = course_pattern.match(line)
        course_match_start = course_start_pattern.match(line)
        course_match_end = course_end_pattern.match(line)

        if end_match:
            # Parse prior_course to add substitutions
            prior_course = current_course
            if prior_course is not None:
                prior_course = get_substitutions(course=prior_course)
            # Start a new course
            current_course = None
            continue

        elif start_course:
            # Parse prior_course to add substitutions
            prior_course = current_course
            if prior_course is not None:
                prior_course = get_substitutions(course=prior_course)
            # Add the second half of a two-line course title
            if course_match_end:
                course_title2, course_credit = course_match_end.groups()
                course_title = course_title1.strip() + ' ' + course_title2.strip()
                current_course = create_new_course(course_name, course_title, course_credit)
                courses.append(current_course)
                start_course = False

        elif course_match:
            # Parse prior_course to add substitutions
            prior_course = current_course
            if prior_course is not None:
                prior_course = get_substitutions(course=prior_course)

            # If we find a course line, extract information and start a new course
            course_name, course_title, course_credit = course_match.groups()
            current_course = create_new_course(course_name, course_title, course_credit)
            courses.append(current_course)
            start_course = False

        elif course_match_start:
            course_name, course_title1 = course_match_start.groups()
            start_course = True                    
            
        elif current_course is not None:
            # If we are in the middle of a course, add the line to its description
            current_course['description'] += line + '\n'

            ##### Warnings #####

            # Check for course warnings in the description
            if line.startswith("("):
                line = line[1:].strip()
                warnings = True
                
            # for case where warnings are not yet true or false
            if warnings is not None:
                if warnings:
                    # Check if the close parenthesis is in the line
                    closing_parenthesis_index = line.find(")")
                    if closing_parenthesis_index != -1:
                        current_course['warnings'] += line[:closing_parenthesis_index].strip()
                        warnings = False
                    else:
                        current_course['warnings'] += line.strip() + '\n'

            ##### Prerequisites #####
            
            # Check for course prerequisites in the description
            if "Prerequisite:" in line:
                wholematch = prereq_oneline.findall(line)
                if wholematch:
                    prerequisite_text = wholematch[0].strip()
                    current_course['prerequisites'] = prerequisite_text
                    prereq = False
                else:
                    startmatch = prereq_start.findall(line)
                    if startmatch:
                        prerequisite_text = startmatch[0].strip()
                        prereq = True
            elif prereq:
                # assumes prerequisites are on multiple lines
                endmatch = prereq_end.findall(line)
                if endmatch:
                    # Add end of line
                    prerequisite_text += ' ' + endmatch[0].strip()
                    current_course['prerequisites'] = prerequisite_text
                    prereq = False
                else:
                    # Add additional line
                    prerequisite_text += ' ' + line.strip() + '\n'
                    prereq = True

    return courses
